# %%
from collections import defaultdict
# 사업 운영 기간 파서
import json
from dataclasses import dataclass
from typing import List, Optional, Dict, Any
import re
from datetime import datetime, date

# 날짜 패턴별 정규표현식
date_patterns = {
    # 1. YYYY.MM.DD. ~ YYYY.MM.DD. 형식
    'full_date_dots': r'(\d{4})\.(\d{1,2})\.(\d{1,2})\.?\s*~\s*(\d{4})\.(\d{1,2})\.(\d{1,2})\.?',
    'A':"(\d{4})년\s*(\d{1,2})월\s*(\d{1,2})일\s*~\s*(\d{4})년\s*(\d{1,2})월\s*(\d{1,2})일",
    
    # 2. YYYY. MM. ~ YYYY. MM. 형식
    'year_month_dots': r'(\d{4})\.\s*(\d{1,2})\.\s*~\s*(\d{4})\.\s*(\d{1,2})\.',
    
    # 3. YYYY-MM-DD~YYYY-MM-DD 형식
    'full_date_hyphens': r'(\d{4})-(\d{2})-(\d{2})\s*~\s*(\d{4})-(\d{2})-(\d{2})',
    
    # 4. YYYY. M. ~ MM. 형식 (같은 해 다른 달)
    'same_year_months': r'(\d{4})\.\s*(\d{1,2})\.\s*~\s*(\d{1,2})\.',
    
    # 5. 'YY. ~ 'YY. 형식
    'short_years': r'\'(\d{2})\.\s*~\s*\'(\d{2})\.',
    
    # 6. 'YY. MM. ~ 'YY. MM. 형식
    'short_year_month': r'\'(\d{2})\.\s*(\d{1,2})\.\s*~\s*\'(\d{2})\.\s*(\d{1,2})\.',
    
    # 7. YYYY년 MM월 ~ YYYY년 MM월 형식
    'korean_date': r'(\d{4})[년]\s*(\d{1,2})[월]\s*~\s*(\d{4})[년]\s*(\d{1,2})[월]',
    
    # 8. YYYY.M ~ YYYY.MM 형식
    'year_month_minimal': r'(\d{4})\.(\d{1,2})\s*~\s*(\d{4})\.(\d{1,2})',
    
    # 9. [NEW] YYYY. ~ YYYY. 형식 (연도만)
    'years_only': r'(\d{4})\.\s*~\s*(\d{4})\.',

    # 5. 'YY.MM. ~ MM.' 형식 (연도 축약)
    'short_year_month_dots': r"'(\d{2})\.(\d{1,2})\.?\s*~\s*(\d{1,2})\.'",
    
    # 10. [NEW] YYYY. MM. DD.(요일) 형식
    'date_with_day': r'(\d{4})\.\s*(\d{1,2})\.\s*(\d{1,2})\.\s*\([월화수목금토일]\)',
    # 3. YYYY년 MM월 DD일 ~ YYYY년 MM월 DD일(예정) 형식
    'full_date_korean_with_optional_scheduled': r'(\d{4})년\s*(\d{1,2})월\s*(\d{1,2})일\s*~\s*(\d{4})년\s*(\d{1,2})월\s*(\d{1,2})일(?:\(예정\))?',
    
    # 11. [NEW] 특수 케이스 패턴
    'special_cases': r'(연중|예산소진시까지|계속사업|현재|상시|미정|-)',

    'bullet_full_year_month': r'[□○•]\s*(\d{4})\.(\d{1,2})\.\s*~\s*(\d{4})\.(\d{1,2})',  # □2024.3.~2024.12 패턴
    'bullet_short_year_month': r'[□○•][사업|추진]기간:\s*\'(\d{2})\.(\d{1,2})\.\s*~\s*(\d{1,2})\.(?:\s*※.*)?',  # ○사업기간:'24.1.~12. 패턴
    'bullet_period_short': r'[○•]\s*(?:추진|사업)기간:\s*\'(\d{2})\.(\d{1,2})\.\s*~\s*(\d{1,2})\.(?:\s*※.*)?',  # ○추진기간:'24.1.~12.
    'bullet_period_years': r'[•○]\s*사업기간:\s*\'(\d{2})\.(\d{1,2})\.\s*~\s*\'(\d{2})\.(\d{1,2})\.(?:\s*\([^)]+\))?',  # •사업기간:'24.2.~'26.12.
    'year_month_short': r'(\d{4})\.(\d{2})~(\d{2})',  # 2024.02~12
    'year_month_korean': r'(\d{4})\.(\d{1,2})월?\s*~\s*(\d{4})\.(\d{1,2})월?',  # 2024.1월~2024.12월    
    'bullet_period_years_with_note': r'[•○]\s*사업기간:\s*\'(\d{2})\.(\d{1,2})\.\s*~\s*\'(\d{2})\.(\d{1,2})\.\s*\(※[^)]+\)',

}

def convert_to_date(year, month=1, day=1):
    """Convert year, month, day components to datetime object"""
    try:
        return datetime(int(year), int(month) if month else 1, int(day) if day else 1)
    except (ValueError, TypeError):
        return None

def is_policy_active(period, current_date):
    """Check if policy is currently active based on period information"""
    if not period or period.get("type") == "special_case":
        return True
    
    # Start date check
    if period.get("start"):
        start_info = period["start"]
        start_date = convert_to_date(
            start_info.get("year"),
            start_info.get("month"),
            start_info.get("day")
        )
        if start_date and current_date < start_date:
            return False
    
    # End date check
    if period.get("end"):
        end_info = period["end"]
        end_date = convert_to_date(
            end_info.get("year"),
            end_info.get("month"),
            end_info.get("day")
        )
        if end_date and current_date > end_date:
            return False
    
    return True

def parse_date_string(date_str):
    """
    주어진 날짜 문자열에서 시작일과 종료일을 추출
    
    Args:
        date_str (str): 날짜 문자열
    
    Returns:
        dict: 파싱된 날짜 정보 또는 특수 케이스 문자열
    """
    # 특수 케이스 먼저 체크
    special_match = re.search(date_patterns['special_cases'], date_str)
    if special_match:
        return {'type': 'special_case', 'value': special_match.group(1)}
    
    for pattern_name, pattern in date_patterns.items():
        if pattern_name == 'special_cases':
            continue
            
        match = re.search(pattern, date_str)
        if match:
            groups = match.groups()
            
            # 패턴별 결과 처리
            if pattern_name == 'full_date_dots':
                return {
                    'type': 'full_date',
                    'start': {'year': groups[0], 'month': groups[1], 'day': groups[2]},
                    'end': {'year': groups[3], 'month': groups[4], 'day': groups[5]}
                }
            elif pattern_name in ['year_month_dots', 'korean_date', 'year_month_minimal']:
                return {
                    'type': 'year_month',
                    'start': {'year': groups[0], 'month': groups[1]},
                    'end': {'year': groups[2], 'month': groups[3]}
                }
            elif pattern_name == 'full_date_hyphens':
                return {
                    'type': 'full_date',
                    'start': {'year': groups[0], 'month': groups[1], 'day': groups[2]},
                    'end': {'year': groups[3], 'month': groups[4], 'day': groups[5]}
                }
            elif pattern_name == 'same_year_months':
                return {
                    'type': 'same_year_months',
                    'start': {'year': groups[0], 'month': groups[1]},
                    'end': {'year': groups[0], 'month': groups[2]}
                }
            elif pattern_name == 'short_years':
                start_year = '20' + groups[0]
                end_year = '20' + groups[1]
                return {
                    'type': 'years_only',
                    'start': {'year': start_year},
                    'end': {'year': end_year}
                }
            elif pattern_name == 'short_year_month':
                start_year = '20' + groups[0]
                end_year = '20' + groups[2]
                return {
                    'type': 'year_month',
                    'start': {'year': start_year, 'month': groups[1]},
                    'end': {'year': end_year, 'month': groups[3]}
                }
            elif pattern_name == 'years_only':
                return {
                    'type': 'years_only',
                    'start': {'year': groups[0]},
                    'end': {'year': groups[1]}
                }
            elif pattern_name == 'date_with_day':
                return {
                    'type': 'single_date_with_day',
                    'date': {'year': groups[0], 'month': groups[1], 'day': groups[2]}
                }
            elif pattern_name == 'full_date_korean_with_optional_scheduled':
                return {
                    'type': 'full_date_korean_with_optional_scheduled',
                    'start': {'year': groups[0], 'month': groups[1], 'day': groups[2]},
                    'end': {'year': groups[3], 'month': groups[4], 'day': groups[5]}
                }
            elif pattern_name == 'A':
                return {
                    'type': 'A',
                    'start': {'year': groups[0], 'month': groups[1], 'day': groups[2]},
                    'end': {'year': groups[3], 'month': groups[4], 'day': groups[5]}
                }
            elif pattern_name == 'short_year_month_dots':
                return {
                    'type': 'short_year_month_dots',
                    'start': {'year': groups[0], 'month': groups[1]},
                    'end': {'year': groups[0], 'month': groups[2]}
                }
            elif pattern_name == 'bullet_full_year_month':
                return {
                    'type': 'year_month',
                    'start': {'year': groups[0], 'month': groups[1]},
                    'end': {'year': groups[2], 'month': groups[3]}
                }

            elif pattern_name == 'bullet_short_year_month':
                start_year = '20' + groups[0]
                return {
                    'type': 'same_year_months',
                    'start': {'year': start_year, 'month': groups[1]},
                    'end': {'year': start_year, 'month': groups[2]}
                }
            # parse_date_string 함수 내 if-elif 문에 추가
            elif pattern_name == 'bullet_period_short':
                start_year = '20' + groups[0]
                return {
                    'type': 'same_year_months',
                    'start': {'year': start_year, 'month': groups[1]},
                    'end': {'year': start_year, 'month': groups[2]}
                }

            elif pattern_name == 'bullet_period_years':
                start_year = '20' + groups[0]
                end_year = '20' + groups[2]
                return {
                    'type': 'year_month',
                    'start': {'year': start_year, 'month': groups[1]},
                    'end': {'year': end_year, 'month': groups[3]}
                }

            elif pattern_name == 'year_month_short':
                return {
                    'type': 'same_year_months',
                    'start': {'year': groups[0], 'month': groups[1]},
                    'end': {'year': groups[0], 'month': groups[2]}
                }

            elif pattern_name == 'year_month_korean':
                return {
                    'type': 'year_month',
                    'start': {'year': groups[0], 'month': groups[1]},
                    'end': {'year': groups[2], 'month': groups[3]}
                }
            # parse_date_string 함수 내 if-elif 문에 추가
            elif pattern_name == 'bullet_period_years_with_note':
                start_year = '20' + groups[0]
                end_year = '20' + groups[2]
                return {
                    'type': 'year_month',
                    'start': {'year': start_year, 'month': groups[1]},
                    'end': {'year': end_year, 'month': groups[3]}
                }
                
    return None

def parse_operating_periods(text):
    # Regular expression to match date ranges
    status_pattern = r"상시|미정"

    results = []

    for line in text.splitlines():
        # Check for date ranges
        date_match = re.search(date_patterns, line)
        if date_match:
            start_year, start_month, start_day, end_year, end_month, end_day = date_match.groups()
            results.append({
                "start_date": f"{start_year}-{int(start_month):02d}-{int(start_day):02d}",
                "end_date": f"{end_year}-{int(end_month):02d}-{int(end_day):02d}"
            })
        else:
            # Check for '상시' or '미정'
            status_match = re.search(status_pattern, line)
            if status_match:
                results.append({
                    "start_date": "0000-0-0",
                    "end_date": "9999-99-99"
                })

    return results

def extract_age_range(text):
    # 정규 표현식 정의
    age_pattern = r"(?:(?:만\s*)?(\d+)\s*세\s*~\s*(\d+)\s*세|(?:만\s*)?(\d+)\s*세\s*~\s*제한 없음|(?:만\s*)?제한 없음)"
    match = re.search(age_pattern, text)

    if match:
        if match.group(1) and match.group(2):  # "만 19세 ~ 34세" 형태
            min_age = int(match.group(1))
            max_age = int(match.group(2))
        elif match.group(3):  # "만 19세 ~ 제한 없음" 형태
            min_age = int(match.group(3))
            max_age = 9999
        else:  # "제한 없음" 형태
            min_age = 0
            max_age = 9999
    else:
        # 매치되지 않을 경우 기본 값
        min_age = 0
        max_age = 9999

    return min_age, max_age

regions = {
    ("서울"): ["종로", "중구", "용산", "성동", "광진", "동대문", "중랑", "성북", 
             "강북", "도봉", "노원", "은평", "서대문", "마포", "양천", "강서", 
             "구로", "금천", "영등포", "동작", "관악", "서초", "강남", "송파", "강동"],
    ("부산"): ["중구", "서구", "동구", "영도", "부산진", "동래", "남구", "북구", "해운대", 
             "사하", "금정", "강서", "연제", "수영", "사상", "기장"],
    ("대구"): ["중구", "동구", "서구", "남구", "북구", "수성", "달서", "달성"],
    ("인천"): ["중구", "동구", "미추홀", "연수", "남동", "부평", "계양", "서구", "강화", "옹진"],
    ("광주"): ["동구", "서구", "남구", "북구", "광산"],
    ("대전"): ["동구", "중구", "서구", "유성", "대덕"],
    ("울산"): ["중구", "남구", "동구", "북구", "울주"],
    ("세종"): ["세종"],
    ("경기"): ["수원", "성남", "안양", "안산", "용인", "부천", "광명", "평택", 
             "과천", "오산", "시흥", "군포", "의왕", "하남", "이천", "안성", 
             "김포", "화성", "광주", "양주", "포천", "여주", "연천", "가평", "양평"],
    ("강원"): ["춘천", "원주", "강릉", "동해", "태백", "속초", "삼척", 
             "홍천", "횡성", "영월", "평창", "정선", "철원", "화천", "양구", "인제", "고성", "양양"],
    ("충북", "충청북도"): ["청주", "충주", "제천", "보은", "옥천", "영동", "증평", "진천", "괴산", "음성", "단양"],
    ("충남", "충청남도"): ["천안", "공주", "보령", "아산", "서산", "논산", "계룡", "당진", 
             "금산", "부여", "서천", "청양", "홍성", "예산", "태안"],
    ("전북", "전라북도"): ["전주", "군산", "익산", "정읍", "남원", "김제", 
             "완주", "진안", "무주", "장수", "임실", "순창", "고창", "부안"],
    ("전남", "전라남도"): ["목포", "여수", "순천", "나주", "광양", 
             "담양", "곡성", "구례", "고흥", "보성", "화순", "장흥", "강진", "해남", 
             "영암", "무안", "함평", "영광", "장성", "완도", "진도", "신안"],
    ("경북", "경상북도"): ["포항", "경주", "김천", "안동", "구미", "영주", "영천", "상주", 
             "문경", "경산", "군위", "의성", "청송", "영양", "영덕", "청도", 
             "고령", "성주", "칠곡", "예천", "봉화", "울진", "울릉"],
    ("경남", "경상남도"): ["창원", "진주", "통영", "사천", "김해", "밀양", "거제", "양산", 
             "의령", "함안", "창녕", "고성", "남해", "하동", "산청", "함양", "거창", "합천"],
    ("제주"): ["제주", "서귀포"]
}

def classify_regions(entries, regions):
    result = defaultdict(list)

    for entry in entries:
        matched = False
        for regionss in regions.keys():
            if type(regionss)==tuple:
                for region in regionss:
                    if region in entry:
                        result[regionss[0]].append(entry)
                        matched=True
                        break
                if matched:
                    break
            else:
                if regionss in entry:
                    result[regionss].append(entry)
                    matched=True
                    break
        if not matched:
            for region, subregions in regions.items():
                if any(subregion in entry for subregion in subregions):
                    result[region].append(entry)
                    matched = True
                    break
        if not matched:
            result["전국"].append(entry)

    return result




def parse_policy_details(policy_data):
    """Parse and extract relevant details from each policy"""
    parsed_policies = []
    
    for policy in policy_data:
        details = {detail["Title"]: detail["Content"] for detail in policy["Details"]}
        
        parsed_policy = {
            "title": policy["Policy Title"],
            "description": policy["Description"]
        }
        
        # Parse support period
        support_period = "".join(details.get("사업 신청 기간", "__").split())
        if support_period:
            parsed_policy["support_period"] = parse_date_string(support_period)
        
        # Parse operating period
        operating_period = "".join(details.get("사업 운영 기간", "__").split())
        if operating_period:
            parsed_policy["operating_period"] = parse_date_string(operating_period)
        if debugDate:
            if parsed_policy["operating_period"]==None:
                print(operating_period)
            if parsed_policy["support_period"]==None:
                print(support_period)
            
        # Parse age requirements
        age_str = details.get("연령", "제한없음")
        min_age, max_age = extract_age_range(age_str)
        parsed_policy["age_range"] = {
            "min_age": min_age,
            "max_age": max_age if max_age != 9999 else None
        }
        
        # Parse managing organization and region
        managing_org = details.get("주관 기관", "")
        residence_info = details.get("거주지 및 소득", "")
        
        org_regions = classify_regions([managing_org], regions)
        residence_regions = classify_regions([residence_info], regions)
        
        parsed_policy["managing_regions"] = set()
        for region, entries in org_regions.items():
            if entries:
                parsed_policy["managing_regions"].add(region)
                
        parsed_policy["residence_regions"] = set()
        for region, entries in residence_regions.items():
            if entries:
                parsed_policy["residence_regions"].add(region)
        
        parsed_policy["original_link"] = policy.get("Original Link", "")
        parsed_policy["details"] = details
        
        parsed_policies.append(parsed_policy)

        if debug:
            print(f'{age_str}: {parsed_policy["age_range"]}, {support_period}: {parsed_policy["support_period"]}, {operating_period}: {parsed_policy["operating_period"]}, {managing_org}:{parsed_policy["managing_regions"]}, {residence_info}:{parsed_policy["residence_regions"]}')
    
    return parsed_policies

def filter_available_policies(parsed_policies, user_age, user_region, current_date):
    """Filter policies based on user criteria"""
    available_policies = []
    
    for policy in parsed_policies:
        # Check age eligibility
        age_eligible = (
            (policy["age_range"]["min_age"] <= user_age) and 
            (policy["age_range"]["max_age"] is None or user_age <= policy["age_range"]["max_age"])
        )
        
        # Check region eligibility
        region_eligible = (
            "전국" in policy["managing_regions"] or 
            "전국" in policy["residence_regions"] or
            user_region in policy["managing_regions"]
        )
        
        # Check if policy is currently active based on support period
        support_period_active = is_policy_active(
            policy.get("support_period"), 
            current_date
        )
        
        # Check if policy is currently active based on operating period
        operating_period_active = is_policy_active(
            policy.get("operating_period"), 
            current_date
        )
        
        if (age_eligible and 
            region_eligible and 
            support_period_active and 
            operating_period_active):
            available_policies.append({
                "title": policy["title"],
                "description": policy["description"],
                "link": policy["original_link"],
                "details": policy["details"]
            })
    
    return available_policies

def get_policy_recommendations(policy_data, user_age, user_region, current_date_str):
    """Main function to get policy recommendations"""
    # Parse current date
    current_date = datetime.strptime(current_date_str, "%Y-%m-%d")
    
    # Parse all policies
    parsed_policies = parse_policy_details(policy_data)
    
    # Filter available policies
    available_policies = filter_available_policies(
        parsed_policies, 
        user_age, 
        user_region, 
        current_date
    )
    
    return available_policies

# Example usage:

# Sample usage of the system
current_date = "2025-01-10"
user_age = 31
user_region = "대전"
debug=True
debugDate=False

with open('filtered_policies.json', 'r', encoding='utf-8') as f:
        json_data = f.read()
data = json.loads(json_data)
policies = []
recommendations = get_policy_recommendations(
    data,  # Your JSON data
    user_age,
    user_region,
    current_date
)

for idx, policy in enumerate(recommendations, 1):
    print(f"\n=== 추천 정책 {idx} ===")
    print(f"제목: {policy['title']}")
    print(f"설명: {policy['description']}")
    print(f"연령: {policy['details'].get('연령')}")
    print(f"신청: {policy['details'].get('사업 신청 기간')}")
    print(f"기관: {policy['details'].get('주관 기관')}")
    print(f"지역: {policy['details'].get('거주지 및 소득')}")
    print(f"상세 정보: {policy['link']}")
# Out:
# ❍ 지원요건 : 전세사기피해자 결정일 현재 ① 임대차계약을 체결한 피해주택의 소재지가 대전시이고, ② 대전시에 주민등록을 두고 거주하는 자:{'대전'}__: None, 대전 전세피해지원센터:{'대전'}, ❍ 지원대상 : 전세사기피해를 입은 임차인(특별법의 전세사기피해자등, 특별법 시행전 주택도시보증공사에서 전세피해확인서 발급자)
# 만 19세 ~ 39세: {'min_age': 19, 'max_age': 39}, 2024년11월18일~2024년12월31일(예정): {'type': 'A', 'start': {'year': '2024', 'month': '11', 'day': '18'}, 'end': {'year': '2024', 'month': '12', 'day': '31'}}, __: None, 경상북도 건축디자인과:{'경북'}, ｢경상북도 청년 기본조례｣상 청년 신혼부부*(만19세이상~만39세이하)가 월세 주택**에 주민등록상 같이 전입신고 되어 있고, 경북도 내 임차보증금 5천만원 이하면서 월세 80만원 이하에 거주하는 연소득(부부합산) 6천만원 이하인 무주택자:{'경북'}
# 제한없음: {'min_age': 0, 'max_age': None}, 미정: {'type': 'special_case', 'value': '미정'}, 2024.11.05.~2024.12.27.: {'type': 'full_date', 'start': {'year': '2024', 'month': '11', 'day': '05'}, 'end': {'year': '2024', 'month': '12', 'day': '27'}}, 광산구청:{'광주'}, -:{'전국'}
# 만 19세 ~ 39세: {'min_age': 19, 'max_age': 39}, 2024년02월26일~2025년02월25일: {'type': 'A', 'start': {'year': '2024', 'month': '02', 'day': '26'}, 'end': {'year': '2025', 'month': '02', 'day': '25'}}, 2024.2.~2025.2.: {'type': 'year_month', 'start': {'year': '2024', 'month': '2'}, 'end': {'year': '2025', 'month': '2'}}, 인천광역시 청년정책담당관:{'인천'}, ○ 거주지 : 제한없음○ 소득 : ◎ 청약통장 가입 필수(종류무관) ◎ 소득 : (청년독립가구) 기준 중위소득 60%이하 (원가구) 기준 중위소득 100% 이하◎ 재산 : (청년독립가구) 재산 122백만원 이하 (원가구) 재산 470백만원 이하◎ 주택 : 전입신고 필수 ※ 월세 임차보증금 5천만원 및 월세 70만원 이하 요건 폐지(2024.4.12.~시행)] ※ 제출된 신청서를 토대로 공적자료 조회(조사시점 기준 적용)<가구구성 방법> (청년독립가구) 청년 + 배우자 + 직계비속 + 동일 주소지에 거주하는 그 외 「민법」상 가족* (원가구) 청년독립가구 + 1촌 이내 직계혈족(부,모) * (가족의 범위, 민법§779) ❶배우자, 직계혈족 및 형제자매, ❷직계혈족의 배우자, 배우자의 직계혈족 및 배우자의 형제자매(생계를 같이하는 경우에 한함)※ 원가구(부모님) 소득·재산 미고려 : ①30세 이상 ②혼인 ③미혼부·모 ④30세 미만 미혼 청년의 소득이 중위 50% 이상으로 생계를 달리한다고 군수·구청장이 인정하는 경우○ 대상 : 인천 19~39세 이하 부모님과 별도 거주 무주택 청년 - 월세지원 신청연령은 신청년도의 출생년을 기준(19~39세가 되는 해의 1.1.~12.31.)* 신청기간 : 2024. 2. 26. ~ 2025. 2. 25.(1년간):{'인천'}
# ※ 아파트를 제외한 주택유형의 경우 임대인이 신청일 기준 해당 주택 소유기간 3개월 미만인 경우, 보증신청 불가 등 협약은행 내규에 따라 협약은행에서 추가 심사 실시:{'부산'}': '2024', 'month': '02', 'day': '01'}, 'end': {'year': '2024', 'month': '12', 'day': '31'}}, __: None, 부산시:{'부산'}, - 지원대상 : 부산시 주민등록이 되어 있는 19~39세 무주택 청년 세대주(세대주 범위는 공고문 참고)
# 만 19세 ~ 39세: {'min_age': 19, 'max_age': 39}, 상시: {'type': 'special_case', 'value': '상시'}, __: None, 상주시청 미래정책실:{('경북', '경상북도')}, 상주시 청년(만 19세 ~ 39세 이하)이고, 지역 정착 창업사업 참여자:{('경북', '경상북도')}
# ○ (원가구) 청년독립가구 + 1촌이내 직계혈족(부·모):{('전북', '전라북도')} 가족소득 50% 이상으로 생계를 달리한다고 시·군·구청장이 인정하는 경우 등은 원가구 소득 미고려통부:{'전국'}, □ 19세~34세 독립거주 무주택 청년 중 청년가구 소득이 기준 중위소득 60% 이하이면서, 원가구 소득이 중위소득 100% 이하인 청년을 지원합니다.
# 제한없음: {'min_age': 0, 'max_age': None}, 2024년01월01일~2024년12월31일: {'type': 'A', 'start': {'year': '2024', 'month': '01', 'day': '01'}, 'end': {'year': '2024', 'month': '12', 'day': '31'}}, __: None, 의성군 기획예산담당관 인구정책:{('충남', '충청남도')}, · 지원대상: 신청일 기준, 남편 또는 아내가 1년 이상 의성군에 주소를 두고 거주하며, 혼인신고일 이후 부부가 함께 의성군에 주민등록을 둔 결혼 1년 이하 무주택 신혼부부:{('전북', '전라북도')}
# - 법령에서 정한 정기점검 기간이 이미 경과하였거나 점검유예한 주택:{'전국'}09월01일~2024년12월31일: {'type': 'A', 'start': {'year': '2024', 'month': '09', 'day': '01'}, 'end': {'year': '2024', 'month': '12', 'day': '31'}}, __: None, 대전전세피해지원센터:{'대전'}, ○ 대상 : 관내 전세사기피해주택으로 아래를 모두 충족하는 주택
# ※ 보장기관이 인정하는 경우 예외 가능:{'전국'}·군을 달리하는 경우 인정미만의 미혼자녀: 'special_case', 'value': '상시'}, __: None, 국토교통부:{'전국'}, - 소득인정액이 기준중위소득* 48% 이하
#  ○ 소득이 없을 경우 국세청 사실증명원 등 소득이 없다는 증빙서류 필요:{('전북', '전라북도')}2월31일: {'type': 'A', 'start': {'year': '2024', 'month': '01', 'day': '01'}, 'end': {'year': '2024', 'month': '12', 'day': '31'}}, __: None, 고흥군청:{('전남', '전라남도')}, 1. (연령) 신청일 현재 18세 ~ 49세인 청년
# ○ 대상 : 인천 19~39세 이하 부모님과 별도 거주 무주택 청년 - 월세지원 신청연령은 신청년도의 출생년을 기준(19~39세가 되는 해의 1.1.~12.31.)* 신청기간 : 2024. 2. 26. ~ 2025. 2. 25.(1년간):{'인천'} 민법§779) ❶배우자, 직계혈족 및 형제자매, ❷직계혈족의 배우자, 배우자의 직계혈족 및 배우자의 형제자매(생계를 같이하는 경우에 한함)※ 원가구(부모님) 소득·재산 미고려 : ①30세 이상 ②혼인 ③미혼부·모 ④30세 미만 미혼 청년의 소득이 중위 50% 이상으로 생계를 달리한다고 군수·구청장이 인정하는 경우천광역시 청년정책담당관:{'인천'}, ◎ 청약통장 가입 필수(종류무관)
#  * 19~34세 : 국토부(전국) 청년월세 한시특별 지원 / 35~39세 : 인천형 청년월세 지원:{'인천'}기준(19~39세가 되는 해의 1.1.~12.31.)」상 가족* (원가구) 청년독립가구 + 1촌 이내 직계혈족(부,모) * (가족의 범위, 민법§779) ❶배우자, 직계혈족 및 형제자매, ❷직계혈족의 배우자, 배우자의 직계혈족 및 배우자의 형제자매(생계를 같이하는 경우에 한함)※ 원가구(부모님) 소득·재산 미고려 : ①30세 이상 ②혼인(이혼) ③미혼부·모 ④30세 미만 미혼 청년의 소득이 중위 50% 이상으로 생계를 달리한다고 군수·구청장이 인정하는 경우end': {'year': '2025', 'month': '2', 'day': '25'}}, 인천광역시 청년정책담당관:{'인천'}, ◎ 청약통장 가입 필수(종류무관)
# 만 19세 ~ 39세: {'min_age': 19, 'max_age': 39}, 상시: {'type': 'special_case', 'value': '상시'}, __: None, 국토교통부 민간임대정책과:{'전국'}, *입주자 모집공고 확인:{'전국'}
# 공고문 필히 참고:{'서울'}in_age': 19, 'max_age': 39}, 미정: {'type': 'special_case', 'value': '미정'}, __: None, 금천구청 일자리청년과:{'서울'}, 서울시 거주
# 추후 공고문 참고:{'서울'}in_age': 19, 'max_age': 39}, 미정: {'type': 'special_case', 'value': '미정'}, __: None, 금천구청 일자리청년과 청년동행팀:{'서울'}, 서울시 거주
# ○ 이주주택 임대차 계약서 상 임차인은 본 사업 신청인과 동일인일 것:{'전북'} 실제 거주하는 자ecial_case', 'value': '상시'}, -: {'type': 'special_case', 'value': '-'}, 전북특별자치도:{'전북'}, □ 아래 요건을 모두 충족하는 자
# ※ [필독] 기본적으로 전년도 소득증빙자료로 선정여부를 결정하나, 금년도 은행 대출시에도 연령·소득요건은 반드시 유지해야 함:{'세종'}': 'A', 'start': {'year': '2024', 'month': '06', 'day': '03'}, 'end': {'year': '2024', 'month': '12', 'day': '31'}}, -: {'type': 'special_case', 'value': '-'}, -:{'전국'}, □ 19세~39세 무주택 청년 신혼부부 혹은 미혼청년으로 세종시 거주자(전입예정자 포함)
# 만 19세 ~ 29세: {'min_age': 19, 'max_age': 29}, 상시: {'type': 'special_case', 'value': '상시'}, ○사업기간:2024.1.~12.: {'type': 'same_year_months', 'start': {'year': '2024', 'month': '1'}, 'end': {'year': '2024', 'month': '12'}}, 울산광역시 건축정책과 주거지원팀(052-229-4415):{'울산'}, ○ 지원대상 : 주거급여 수급가구 내 만 19세 이상 30세 미만 미혼자녀:{'전국'}
# 만 18세 ~ 39세: {'min_age': 18, 'max_age': 39}, 상시: {'type': 'special_case', 'value': '상시'}, ○사업기간:2022.1.~2025.3.: {'type': 'year_month', 'start': {'year': '2022', 'month': '1'}, 'end': {'year': '2025', 'month': '3'}}, 울산광역시 건축정책과 주거지원팀(052-229-4412):{'울산'}, -:{'전국'}
# 만 18세 ~ 39세: {'min_age': 18, 'max_age': 39}, 상시: {'type': 'special_case', 'value': '상시'}, ○사업기간:2020.12.~2025.12.: {'type': 'year_month', 'start': {'year': '2020', 'month': '12'}, 'end': {'year': '2025', 'month': '12'}}, 울산광역시 건축정책과 주거지원팀(052-229-4414):{'울산'}, -:{'전국'}
# 만 18세 ~ 39세: {'min_age': 18, 'max_age': 39}, 상시: {'type': 'special_case', 'value': '상시'}, ○사업기간:2024.1.~2025.7.: {'type': 'year_month', 'start': {'year': '2024', 'month': '1'}, 'end': {'year': '2025', 'month': '7'}}, 울산광역시 건축정책과 주거지원팀(052-229-4413):{'울산'}, -:{'전국'}
# 만 19세 ~ 39세: {'min_age': 19, 'max_age': 39}, 상시: {'type': 'special_case', 'value': '상시'}, ○사업기간:2023.5.~2026.5.: {'type': 'year_month', 'start': {'year': '2023', 'month': '5'}, 'end': {'year': '2026', 'month': '5'}}, 울산광역시 건축정책과 주거지원팀(052-229-4412):{'울산'}, -:{'전국'}
# 만 18세 ~ 39세: {'min_age': 18, 'max_age': 39}, 상시: {'type': 'special_case', 'value': '상시'}, ○사업기간:2023.5.~2026.5.: {'type': 'year_month', 'start': {'year': '2023', 'month': '5'}, 'end': {'year': '2026', 'month': '5'}}, 울산광역시 건축정책과 주거지원팀(052-229-4412):{'울산'}, -:{'전국'}
# 만 18세 ~ 39세: {'min_age': 18, 'max_age': 39}, 상시: {'type': 'special_case', 'value': '상시'}, ○사업기간:2023.5.~2026.5.: {'type': 'year_month', 'start': {'year': '2023', 'month': '5'}, 'end': {'year': '2026', 'month': '5'}}, 울산광역시 건축정책과 주거지원팀(052-229-4412):{'울산'}, -:{'전국'}
# 만 18세 ~ 39세: {'min_age': 18, 'max_age': 39}, 상시: {'type': 'special_case', 'value': '상시'}, ○사업기간:2023.5.~2026.5.: {'type': 'year_month', 'start': {'year': '2023', 'month': '5'}, 'end': {'year': '2026', 'month': '5'}}, 울산광역시 건축정책과 주거지원팀 (052-229-4412):{'울산'}, -:{'전국'}
# 만 18세 ~ 39세: {'min_age': 18, 'max_age': 39}, 상시: {'type': 'special_case', 'value': '상시'}, ○사업기간:2023.5~2026.5: {'type': 'year_month', 'start': {'year': '2023', 'month': '5'}, 'end': {'year': '2026', 'month': '5'}}, 울산광역시 건축정책과 주거지원팀(052-229-4412):{'울산'}, -:{'전국'}
# 만 18세 ~ 39세: {'min_age': 18, 'max_age': 39}, 상시: {'type': 'special_case', 'value': '상시'}, ○사업기간:2022.1.~2025.11.: {'type': 'year_month', 'start': {'year': '2022', 'month': '1'}, 'end': {'year': '2025', 'month': '11'}}, 울산광역시 건축정책과 주거지원팀 (052-229-4412):{'울산'}, -:{'전국'}
# 만 18세 ~ 39세: {'min_age': 18, 'max_age': 39}, 상시: {'type': 'special_case', 'value': '상시'}, ○사업기간:2019.8.~2024.1.: {'type': 'year_month', 'start': {'year': '2019', 'month': '8'}, 'end': {'year': '2024', 'month': '1'}}, 울산광역시 건축정책과 주거지원팀 (052-229-4412):{'울산'}, -:{'전국'}
# 제한없음: {'min_age': 0, 'max_age': None}, 상시: {'type': 'special_case', 'value': '상시'}, ○사업기간:2017.~2026.: {'type': 'years_only', 'start': {'year': '2017'}, 'end': {'year': '2026'}}, 울산도시공사 주택사업팀(052-219-8457):{'울산'}, -:{'전국'}
# 만 19세 ~ 29세: {'min_age': 19, 'max_age': 29}, 상시: {'type': 'special_case', 'value': '상시'}, ○사업기간:연중: {'type': 'special_case', 'value': '연중'}, 울산광역시 북구 노인장애인과 생활보장팀(052-241-7623):{'울산'}, -:{'전국'}
# 만 19세 ~ 39세: {'min_age': 19, 'max_age': 39}, 상시: {'type': 'special_case', 'value': '상시'}, ○사업기간:'19.4.~'26.8.: {'type': 'year_month', 'start': {'year': '2019', 'month': '4'}, 'end': {'year': '2026', 'month': '8'}}, 울산광역시 북구 건축정책과 주택허가팀(052-214-8022):{'울산'}, -:{'전국'}
# 만 19세 ~ 39세: {'min_age': 19, 'max_age': 39}, 상시: {'type': 'special_case', 'value': '상시'}, ○사업기간:'17.~'26.: {'type': 'years_only', 'start': {'year': '2017'}, 'end': {'year': '2026'}}, 울산광역시 북구 건축정책과 주택허가팀(052-241-8022):{'울산'}, -:{'전국'}
# 만 18세 ~ 39세: {'min_age': 18, 'max_age': 39}, 상시: {'type': 'special_case', 'value': '상시'}, ○기간:'23.~계속사업: {'type': 'special_case', 'value': '계속사업'}, 울산광역시 동구 건축주택과 주택허가팀(052-209-3792):{'울산'}, ○ 대 상 : 18세 이상 39세 이하 무주택 청년노동자:{('전북', '전라북도')}
# 만 19세 ~ 30세: {'min_age': 19, 'max_age': 30}, 상시: {'type': 'special_case', 'value': '상시'}, ○추진기간:'24.1.~12.: {'type': 'same_year_months', 'start': {'year': '2024', 'month': '1'}, 'end': {'year': '2024', 'month': '12'}}, 울산광역시 동구 노인장애인과 생활보장팀(052-209-3453):{'울산'}, ○ 지원대상 : 주거급여 수급자의 19세 ~ 30세 미만의 미혼자녀:{'전국'}
# 만 18세 ~ 39세: {'min_age': 18, 'max_age': 39}, 상시: {'type': 'special_case', 'value': '상시'}, ○사업기간:'24.1.~12.: {'type': 'same_year_months', 'start': {'year': '2024', 'month': '1'}, 'end': {'year': '2024', 'month': '12'}}, 욿산광역시 동구 일자리정책과 청년정책팀(052-209-3486):{'부산'}, ○ 대 상 : 동구 거주 또는 생활 청년(18세 ~ 39세):{'부산'}
# 만 18세 ~ 34세: {'min_age': 18, 'max_age': 34}, 상시: {'type': 'special_case', 'value': '상시'}, ○사업기간:'24.1.~12.※2019년중구지회협약에따른연장: {'type': 'same_year_months', 'start': {'year': '2024', 'month': '1'}, 'end': {'year': '2024', 'month': '12'}}, 울산광역시 중구청 민원지적과(052-290-3485):{'울산'}, ○ 지원대상 : 중구에 거주·생활 또는 전입예정인 18세 ~ 34세 이하 청년:{'서울'}
# ❍(주택소유여부) 가족관계증명서의 본인 및 배우자 소유 주택이 없을 것:{('전북', '전라북도')}~2024년12월31일: {'type': 'A', 'start': {'year': '2024', 'month': '06', 'day': '24'}, 'end': {'year': '2024', 'month': '12', 'day': '31'}}, -: {'type': 'special_case', 'value': '-'}, 남원시:{('전북', '전라북도')}, 아래의 요건을 모두 충족하는 청년
# ※ 아파트, 자가 거주자, 기 지원자 제외:{'광주'}: None}, 상시: {'type': 'special_case', 'value': '상시'}, __: None, 광산구청 여성아동과:{'광주'}, 광산구 거주 여성 1인 가구
# ② 2022~2023년 청년 1인 가구 생활안전키트를 지원받지 아니한 사람:{'서울'}4년06월18일~2024년12월31일: {'type': 'A', 'start': {'year': '2024', 'month': '06', 'day': '18'}, 'end': {'year': '2024', 'month': '12', 'day': '31'}}, __: None, 도봉구청 청년미래과:{'서울'}, ○ 신청자격 (아래 요건을 모두 충족하여야 함)
# ○ 대상 : 19세 이상 39세 이하 무주택 미혼 청년:{('전북', '전라북도')}: {'type': 'special_case', 'value': '미정'}, 2024.1.~12.: {'type': 'same_year_months', 'start': {'year': '2024', 'month': '1'}, 'end': {'year': '2024', 'month': '12'}}, 인천광역시 주택정책과:{'인천'}, ○ 거주지 : 제한없음
# ④ (제외) 주거급여수급자, 울주군 신혼부부 주거지원 사업 대상자와 중복 지급불가:{'울산'}하고 있는 가구①~④요건 모두 만족) ype': 'A', 'start': {'year': '2024', 'month': '01', 'day': '01'}, 'end': {'year': '2024', 'month': '12', 'day': '31'}}, -: {'type': 'special_case', 'value': '-'}, 울산광역시청 건축정책과 주거복지담당 (☏ 052-229-4415):{'울산'}, □ 지원대상 : 다음 조건을 모두 만족하는 가구
# - 부부합산소득이 기준중위소득 200%(7,365천원) 이하인 가구(2인 기준):{'울산'}부024년12월31일: {'type': 'A', 'start': {'year': '2024', 'month': '01', 'day': '01'}, 'end': {'year': '2024', 'month': '12', 'day': '31'}}, -: {'type': 'special_case', 'value': '-'}, 울산광역시 울주군 여성가족과 여성가족팀(052-204-1014):{'울산'}, □ 지원대상(아래의 조건을 모두 충족)
# ** 준주택 : 기숙사, 고시원, 오피스텔 등:{('전북', '전라북도')} 목적으로 하는 시설, 임차보증금과 월세 제한 없음{'type': 'A', 'start': {'year': '2024', 'month': '02', 'day': '26'}, 'end': {'year': '2025', 'month': '02', 'day': '25'}}, -: {'type': 'special_case', 'value': '-'}, 국토교통부 (민원 콜센터 : 1600-0777):{'전국'}, □ 지원대상
# ** 준주택 : 기숙사, 고시원, 오피스텔 등:{('전북', '전라북도')} 목적으로 하는 시설, 임차보증금과 월세 제한 없음{'type': 'A', 'start': {'year': '2024', 'month': '02', 'day': '26'}, 'end': {'year': '2025', 'month': '02', 'day': '25'}}, -: {'type': 'special_case', 'value': '-'}, 국토교통부 (민원 콜센터 : 1600-0777):{'전국'}, □ 지원대상
# ** 준주택 : 기숙사, 고시원, 오피스텔 등:{('전북', '전라북도')} 목적으로 하는 시설, 임차보증금과 월세 제한 없음{'type': 'A', 'start': {'year': '2024', 'month': '02', 'day': '26'}, 'end': {'year': '2025', 'month': '02', 'day': '25'}}, -: {'type': 'special_case', 'value': '-'}, 국토교통부 (민원 콜센터 : 1600-0777):{'전국'}, □ 지원대상
# ** 준주택 : 기숙사, 고시원, 오피스텔 등:{('전북', '전라북도')} 목적으로 하는 시설, 임차보증금과 월세 제한 없음{'type': 'A', 'start': {'year': '2024', 'month': '02', 'day': '26'}, 'end': {'year': '2025', 'month': '02', 'day': '25'}}, -: {'type': 'special_case', 'value': '-'}, 국토교통부 (민원 콜센터 : 1600-0777):{'전국'}, □ 지원대상
# ** 준주택 : 기숙사, 고시원, 오피스텔 등:{('전북', '전라북도')} 목적으로 하는 시설, 임차보증금과 월세 제한 없음{'type': 'A', 'start': {'year': '2024', 'month': '02', 'day': '26'}, 'end': {'year': '2025', 'month': '02', 'day': '25'}}, -: {'type': 'special_case', 'value': '-'}, 국토교통부 (민원 콜센터 : 1600-0777):{'전국'}, □ 지원대상
# ○ 주택 : 임대차계약 보증금이 3억원 이하인 주민등록 주소지와 일치하는 주거용 주택:{'울산'} 가입된 경우 신청 가능 (2024. 6. 30. 이전 신청자에 한함.)'year': '2024', 'month': '03', 'day': '04'}, 'end': {'year': '2024', 'month': '12', 'day': '31'}}, -: {'type': 'special_case', 'value': '-'}, 울산광역시 북구 건축주택과(052-241-8029):{'울산'}, □ 지원대상
# 만 19세 ~ 39세: {'min_age': 19, 'max_age': 39}, 상시: {'type': 'special_case', 'value': '상시'}, -: {'type': 'special_case', 'value': '-'}, 김해시청 공동주택과 저소득주거지원팀(☎ 055-330-4318):{('경남', '경상남도')}, □ 신청대상 : 입주자 모집 공고일(2024. 5. 30.) 현재 만19세 이상 만39세 이하의 청년으로 전년도 도시근로자 월평균소득의 120% (4,179,557원)이하인 자:{'전국'}
# 만 19세 ~ 39세: {'min_age': 19, 'max_age': 39}, 2024년01월01일~2024년12월31일: {'type': 'A', 'start': {'year': '2024', 'month': '01', 'day': '01'}, 'end': {'year': '2024', 'month': '12', 'day': '31'}}, __: None, 제주특별자치도 / 경제일자리과:{'제주'}, :{'전국'}
# 만 19세 ~ 39세: {'min_age': 19, 'max_age': 39}, 미정: {'type': 'special_case', 'value': '미정'}, __: None, 제주특별자치도 / 주택토지과(주거복지팀):{'제주'}, :{'전국'}
# 제한없음: {'min_age': 0, 'max_age': None}, 미정: {'type': 'special_case', 'value': '미정'}, __: None, 제주특별자치도 / 주거복지팀:{'제주'}, 지역기준: 제주도, 제주시, 서귀포시:{'제주'}
#   ○ 19세∼39세(무주택 저소득 청년)·신혼부부·고령자 등:{('전북', '전라북도')}1월01일~2024년12월31일: {'type': 'A', 'start': {'year': '2024', 'month': '01', 'day': '01'}, 'end': {'year': '2024', 'month': '12', 'day': '31'}}, __: None, 제주특별자치도:{'제주'}, □ 지원 대상자
# *보증기관: 주택도시보증공사(HUG), 한국주택금융공사(HF), 서울보증보험(SGI):{'서울'}택자(본인 및 배우자 모두 무주택자) : 'A', 'start': {'year': '2024', 'month': '03', 'day': '04'}, 'end': {'year': '2024', 'month': '12', 'day': '31'}}, 2024.1.~12.: {'type': 'same_year_months', 'start': {'year': '2024', 'month': '1'}, 'end': {'year': '2024', 'month': '12'}}, 국토교통부:{'전국'}, ◉ 소득기준
# 제한없음: {'min_age': 0, 'max_age': None}, 상시: {'type': 'special_case', 'value': '상시'}, -: {'type': 'special_case', 'value': '-'}, □ 사하구청 일자리복지과:{'부산'}, □ 19-34세 부모님과 별도로 거주하는 무주택 청년:{('전북', '전라북도')}
# ※ 제외대상 : 아파트 및 오피스텔 거주자, 자가 소유자:{'경기'} 상시: {'type': 'special_case', 'value': '상시'}, __: None, □ 문의전화 : 성남시 여성가족과(☎031-729-8547):{'경기'}, □ 지원대상 (모두 충족해야 함)
# ▶ 아동복지시설 :  아동양육시설, 공동생활가정, 가정위탁:{('전북', '전라북도')}는 중도 퇴소(예정)한 29세 이하 청년 'value': '상시'}, __: None, ○ 경기도 수원시청 도시재생과 주거복지팀(☎031-228-3028):{'경기'}, ○ 신청대상
# 만 19세 ~ 39세: {'min_age': 19, 'max_age': 39}, 상시: {'type': 'special_case', 'value': '상시'}, -: {'type': 'special_case', 'value': '-'}, 전략주택공급과:{'전국'}, -:{'전국'}
# ※ 2024년 3월 1일 이후 접수자부터 아래의 신청자격 기준 적용:{('충남', '충청남도')}pecial_case', 'value': '상시'}, -: {'type': 'special_case', 'value': '-'}, 주택정책과:{'전국'}, - 청년안심주택(공공지원민간임대) 신규 입주예정자 중 아래의 소득 및 자산 기준을 충족하는 자
# * 사실혼인 경우 사실혼관계증명 필요(제3자와 혼인관계 없으며, 1년 이상 동거해야 함. 주민등록등본 추가 제출):{'전국'}로 부모와 생계를 달리하는 청년art': {'year': '2024', 'month': '02', 'day': '26'}, 'end': {'year': '2024', 'month': '12', 'day': '31'}}, •사업기간:’24.2.~‘26.12.(※신청기간:‘24.2.26.부터1년간): None, 세종시청:{'세종'}, ❶ (청년가구) 청년+배우자+직계비속+동일 주소지에 거주중인 「민법상」가족
#   ※ 45세 이하:{'전국'}n_age': 18, 'max_age': 45}, 상시: {'type': 'special_case', 'value': '상시'}, □2024.1.~예산소진시까지: {'type': 'special_case', 'value': '예산소진시까지'}, □ 예산군:{('충남', '충청남도')}, □ 신청일 기준, 군에 주민등록이 되어있는 18세 ~ 45세 이하의 세대주 청년 또는 혼인신고일 기준 5년 미만인 신혼부부
#   ※ 원가구 : 청년가구+1촌이내 직계혈족(부모):{'전국'}민법상 가족이하, 2024년02월26일~2025년02월25일: {'type': 'A', 'start': {'year': '2024', 'month': '02', 'day': '26'}, 'end': {'year': '2025', 'month': '02', 'day': '25'}}, □신청기간:2024.2.26.(월)~2025.2.25.(화)□지급기간:2024.3월~2026.12월: {'type': 'single_date_with_day', 'date': {'year': '2024', 'month': '2', 'day': '26'}}, □ 국토교통부:{'전국'}, □ 요   건
# 만 20세 ~ 49세: {'min_age': 20, 'max_age': 49}, 상시: {'type': 'special_case', 'value': '상시'}, □2024.1.1.~2024.12.31.: {'type': 'full_date', 'start': {'year': '2024', 'month': '1', 'day': '1'}, 'end': {'year': '2024', 'month': '12', 'day': '31'}}, □ 예산군 농업기술센터:{('충남', '충청남도')}, □ 예산군으로 귀농하고자 하는 20~40대 예비귀농인:{('충남', '충청남도')}
# 만 25세 ~ 35세: {'min_age': 25, 'max_age': 35}, 상시: {'type': 'special_case', 'value': '상시'}, □2024-01-01~2024-12-31: {'type': 'special_case', 'value': '-'}, □ 청양군:{('충남', '충청남도')}, □ 다른 시‧군‧구에서 전입일을 기준으로 1년이상 주소를 두고 있다가 군 내에 전입한 자:{'전국'}
# 만 18세 ~ 39세: {'min_age': 18, 'max_age': 39}, 상시: {'type': 'special_case', 'value': '상시'}, □2018.5.~현재: {'type': 'special_case', 'value': '현재'}, □ 부여시청:{('충남', '충청남도')}, □ 부여군 주민등록을 두고 거주하거나 거주 예정인 무주택 청년:{('충남', '충청남도')}
# 만 19세 ~ 34세: {'min_age': 19, 'max_age': 34}, 2024년02월26일~2025년02월25일: {'type': 'A', 'start': {'year': '2024', 'month': '02', 'day': '26'}, 'end': {'year': '2025', 'month': '02', 'day': '25'}}, 2022-08-22~2026-12-31: {'type': 'special_case', 'value': '-'}, 국토교통부:{'전국'}, □ 대상자 : ⌜청년기본법⌟상 청년(만 19~34세 이하)으로 부모님과 별도 거주하는 무주택자:{('전북', '전라북도')}
# (※ 자세한 사항 공고문 참고):{('전북', '전라북도')} 최저주거기준의 주거면적에 미달하는 주택을 소유하고 있는 자를 말함', 'value': '상시'}, -: {'type': 'special_case', 'value': '-'}, 통영시청 기획예산실 인구청년정책팀 ☎055-650-3162:{('충남', '충청남도')}, □ 신청대상: 공고일 기준 18세 이상 45세 이하면서 다음 자격조건을 모두 충족하는 자
# ㅇ기혼자:부부및자녀등포함가구원수계산(최소2인):{('전북', '전라북도')}인경우1인기준적용형제·자매는가구원수에서제외),부모합산소득으로판별(본인소득제외)정'}, □2024.1.22.~2024.12.31.: {'type': 'full_date', 'start': {'year': '2024', 'month': '1', 'day': '22'}, 'end': {'year': '2024', 'month': '12', 'day': '31'}}, □ 청년정책관:{'전국'}, □ 신청일 현재 기준 중위소득 150% 이하에 해당하는 무주택자
# -건강보험증(사본) *건강보험 자격확인(통보)서 대체 가능:{'전국'} 45}, 상시: {'type': 'special_case', 'value': '상시'}, □2024.1.~예산소진시까지: {'type': 'special_case', 'value': '예산소진시까지'}, □ 예산군 총무과:{('충남', '충청남도')}, -서약서
#  ※ 18~39세:{('충남', '충청남도')}8, 'max_age': 39}, 상시: {'type': 'special_case', 'value': '상시'}, □2024.01.01.~2024.12.31.: {'type': 'full_date', 'start': {'year': '2024', 'month': '01', 'day': '01'}, 'end': {'year': '2024', 'month': '12', 'day': '31'}}, □ 인구가족과:{'전국'}, □ 금산군에 거주 또는 직장을 두거나, 활동·생활하고자 하는 무주택 청년
# ○ (원가구) 기준중위소득 100%이하&(청년독립가구) 기준 중위소득 60%이하:{('전북', '전라북도')}년02월25일: {'type': 'A', 'start': {'year': '2024', 'month': '02', 'day': '26'}, 'end': {'year': '2025', 'month': '02', 'day': '25'}}, -: {'type': 'special_case', 'value': '-'}, 국토교통부:{'전국'}, □ 신청일 기준 익산시(주민등록) 거주,  19~34세 이하 부모와 별도 거주 무주택 청년(청약저축 가입자)
# 만 19세 ~ 39세: {'min_age': 19, 'max_age': 39}, 상시: {'type': 'special_case', 'value': '상시'}, __: None, 제주특별자치도 / 주택토지과(주거복지팀):{'제주'}, :{'전국'}
# ❍ 지원자격 : 청년가구 소득 기준 중위소득 60% 이하, 원가구 소득 기준 중위소득 100% 이하:{('전북', '전라북도')}type': 'A', 'start': {'year': '2024', 'month': '02', 'day': '26'}, 'end': {'year': '2025', 'month': '02', 'day': '25'}}, 2024-02-26~2026-12-31: {'type': 'special_case', 'value': '-'}, 국토교통부:{'전국'}, □ 대상자
# 만 19세 ~ 39세: {'min_age': 19, 'max_age': 39}, 2024년01월01일~2024년12월31일: {'type': 'A', 'start': {'year': '2024', 'month': '01', 'day': '01'}, 'end': {'year': '2024', 'month': '12', 'day': '31'}}, __: None, 제주특별자치도 / 주택토지과(주택정책팀):{'제주'}, 지역기준 : 제주도, 제주시, 서귀포시:{'제주'}
# 만 19세 ~ 39세: {'min_age': 19, 'max_age': 39}, 2024년01월01일~2024년12월31일: {'type': 'A', 'start': {'year': '2024', 'month': '01', 'day': '01'}, 'end': {'year': '2024', 'month': '12', 'day': '31'}}, 사업기간2024-01-01~2024-12-31: {'type': 'special_case', 'value': '-'}, 국토교통부:{'전국'}, 지역기준 : 제주도, 제주시, 서귀포시:{'제주'}
# 만 19세 ~ 39세: {'min_age': 19, 'max_age': 39}, 상시: {'type': 'special_case', 'value': '상시'}, 2024.01.01.~2024.12.31.: {'type': 'full_date', 'start': {'year': '2024', 'month': '01', 'day': '01'}, 'end': {'year': '2024', 'month': '12', 'day': '31'}}, 광주광역시 동구청 청년체육과:{'광주'}, -:{'전국'}
# 제한없음: {'min_age': 0, 'max_age': None}, 상시: {'type': 'special_case', 'value': '상시'}, __: None, 서울시청 여성가족정책실- 1인가구담당관:{'서울'}, 서울시 거주 또는 거주예정인 1인가구:{'서울'}
# 만 19세 ~ 45세: {'min_age': 19, 'max_age': 45}, 상시: {'type': 'special_case', 'value': '상시'}, 2024-01-01~2024-12-31: {'type': 'special_case', 'value': '-'}, 상주시:{('경북', '경상북도')}, -:{'전국'}
# ○ 대상 : 인천 19~39세 이하 부모님과 별도 거주 무주택 청년 - 월세지원 신청연령은 신청년도의 출생년을 기준(19~39세가 되는 해의 1.1.~12.31.)* 신청기간 : 2024. 2. 26. ~ 2025. 2. 25.(1년간):{'인천'}족의 범위, 민법§779) ❶배우자, 직계혈족 및 형제자매, ❷직계혈족의 배우자, 배우자의 직계혈족 및 배우자의 형제자매(생계를 같이하는 경우에 한함)※ 원가구(부모님) 소득·재산 미고려 : ①30세 이상 ②혼인 ③미혼부·모 ④30세 미만 미혼 청년의 소득이 중위 50% 이상으로 생계를 달리한다고 군수·구청장이 인정하는 경우년정책담당관:{'인천'}, ㅁ 거주지 : 제한없음
# ○ 대상 : 인천 19~39세 이하 부모님과 별도 거주 무주택 청년 - 월세지원 신청연령은 신청년도의 출생년을 기준(19~39세가 되는 해의 1.1.~12.31.)* 신청기간 : 2024. 2. 26. ~ 2025. 2. 25.(1년간):{'인천'}족의 범위, 민법§779) ❶배우자, 직계혈족 및 형제자매, ❷직계혈족의 배우자, 배우자의 직계혈족 및 배우자의 형제자매(생계를 같이하는 경우에 한함)※ 원가구(부모님) 소득·재산 미고려 : ①30세 이상 ②혼인 ③미혼부·모 ④30세 미만 미혼 청년의 소득이 중위 50% 이상으로 생계를 달리한다고 군수·구청장이 인정하는 경우년정책담당관:{'인천'}, ㅁ 거주지 : 제한없음
# ○ 대상 : 인천 19~39세 이하 부모님과 별도 거주 무주택 청년 - 월세지원 신청연령은 신청년도의 출생년을 기준(19~39세가 되는 해의 1.1.~12.31.)* 신청기간 : 2024. 2. 26. ~ 2025. 2. 25.(1년간):{'인천'}족의 범위, 민법§779) ❶배우자, 직계혈족 및 형제자매, ❷직계혈족의 배우자, 배우자의 직계혈족 및 배우자의 형제자매(생계를 같이하는 경우에 한함)※ 원가구(부모님) 소득·재산 미고려 : ①30세 이상 ②혼인 ③미혼부·모 ④30세 미만 미혼 청년의 소득이 중위 50% 이상으로 생계를 달리한다고 군수·구청장이 인정하는 경우년정책담당관:{'인천'}, ㅁ 거주지 : 제한없음
# ○ 대상 : 인천 19~39세 이하 부모님과 별도 거주 무주택 청년 - 월세지원 신청연령은 신청년도의 출생년을 기준(19~39세가 되는 해의 1.1.~12.31.)* 신청기간 : 2024. 2. 26. ~ 2025. 2. 25.(1년간):{'인천'}족의 범위, 민법§779) ❶배우자, 직계혈족 및 형제자매, ❷직계혈족의 배우자, 배우자의 직계혈족 및 배우자의 형제자매(생계를 같이하는 경우에 한함)※ 원가구(부모님) 소득·재산 미고려 : ①30세 이상 ②혼인 ③미혼부·모 ④30세 미만 미혼 청년의 소득이 중위 50% 이상으로 생계를 달리한다고 군수·구청장이 인정하는 경우년정책담당관:{'인천'}, ㅁ 거주지 : 제한없음
# ○ 대상 : 인천 19~39세 이하 부모님과 별도 거주 무주택 청년 - 월세지원 신청연령은 신청년도의 출생년을 기준(19~39세가 되는 해의 1.1.~12.31.)* 신청기간 : 2024. 2. 26. ~ 2025. 2. 25.(1년간):{'인천'}족의 범위, 민법§779) ❶배우자, 직계혈족 및 형제자매, ❷직계혈족의 배우자, 배우자의 직계혈족 및 배우자의 형제자매(생계를 같이하는 경우에 한함)※ 원가구(부모님) 소득·재산 미고려 : ①30세 이상 ②혼인 ③미혼부·모 ④30세 미만 미혼 청년의 소득이 중위 50% 이상으로 생계를 달리한다고 군수·구청장이 인정하는 경우년정책담당관:{'인천'}, ㅁ 거주지 : 제한없음
# ○ 대상 : 인천 19~39세 이하 부모님과 별도 거주 무주택 청년 - 월세지원 신청연령은 신청년도의 출생년을 기준(19~39세가 되는 해의 1.1.~12.31.)* 신청기간 : 2024. 2. 26. ~ 2025. 2. 25.(1년간):{'인천'}족의 범위, 민법§779) ❶배우자, 직계혈족 및 형제자매, ❷직계혈족의 배우자, 배우자의 직계혈족 및 배우자의 형제자매(생계를 같이하는 경우에 한함)※ 원가구(부모님) 소득·재산 미고려 : ①30세 이상 ②혼인 ③미혼부·모 ④30세 미만 미혼 청년의 소득이 중위 50% 이상으로 생계를 달리한다고 군수·구청장이 인정하는 경우년정책담당관:{'인천'}, ㅁ 거주지 : 제한없음
#  ※ 거주하는 본인 또는 시민 자녀:{('충남', '충청남도')}e': 34}, 2024년02월01일~2025년02월31일: {'type': 'A', 'start': {'year': '2024', 'month': '02', 'day': '01'}, 'end': {'year': '2025', 'month': '02', 'day': '31'}}, □2024.3.~2026.12.: {'type': 'year_month', 'start': {'year': '2024', 'month': '3'}, 'end': {'year': '2026', 'month': '12'}}, □ 국토교통부:{'전국'}, □ 논산시 1년이상 주소를 둔자
# 만 18세 ~ 45세: {'min_age': 18, 'max_age': 45}, 미정: {'type': 'special_case', 'value': '미정'}, 2024-03-11~2024-12-20: {'type': 'special_case', 'value': '-'}, 고령군:{('경북', '경상북도')}, -:{'전국'}
# 만 18세 ~ 29세: {'min_age': 18, 'max_age': 29}, 상시: {'type': 'special_case', 'value': '상시'}, __: None, 경기도 용인시:{'경기'}, :{'전국'}
# 만 19세 ~ 34세: {'min_age': 19, 'max_age': 34}, 2024년03월01일~2024년12월31일: {'type': 'A', 'start': {'year': '2024', 'month': '03', 'day': '01'}, 'end': {'year': '2024', 'month': '12', 'day': '31'}}, □2024.3.~2024.12: {'type': 'year_month', 'start': {'year': '2024', 'month': '3'}, 'end': {'year': '2024', 'month': '12'}}, □ 아산시:{('충남', '충청남도')}, □ 부모와 별도 거주하는 무주택 저소득 청년:{('전북', '전라북도')}
# □ 가구소득인정액이 기준중위소득 180%이하인 자:{('충남', '충청남도')} 상시: {'type': 'special_case', 'value': '상시'}, □2024.01.01.~2024.12.31.: {'type': 'full_date', 'start': {'year': '2024', 'month': '01', 'day': '01'}, 'end': {'year': '2024', 'month': '12', 'day': '31'}}, □ 보령시청:{('충남', '충청남도')}, □ 지원 신청일 현재 보령시에 주민등록을 두고 있거나, 보령시 주택구입자금 또는 전월세보증금 대출 후 1개월 이내 전입 예정자
#   - 건축물대장상 주택이 아닌 곳과 불법건축물, 다중 주택, 공공임대주택은 지원 불가:{'서울'} 이하의 전월세계약하인 자se', 'value': '상시'}, __: None, 서울시 주택정책과:{'서울'}, ○ 지원대상
#    - 신혼부부 : 신혼부부 및 자녀 합산 자산 기준 3억 4,500만원 이하:{'전국'}월평균 소득 120%이하(2인가구:6,498,854원 / 3인가구:8.638.379원) 서울시청 전략주택공급과:{'서울'}, ○ 소득기준(2024년 3월 1일 이후 접수자 기준)
# 만 19세 ~ 34세: {'min_age': 19, 'max_age': 34}, 2024년03월04일~2024년12월31일: {'type': 'A', 'start': {'year': '2024', 'month': '03', 'day': '04'}, 'end': {'year': '2024', 'month': '12', 'day': '31'}}, __: None, 경기도 성남시:{'경기'}, 기타 자세한 모집요강 및 세부 내용은 첨부된 공고문 참고:{'전국'}
# □ 월세가 70만원이 초과되더라도 보증금의 월세환산액(연 5.5%)과 월세액의 합계액이 90만원 이하의 경우는 지원:{('전북', '전라북도')}', 'start': {'year': '2024', 'month': '02', 'day': '26'}, 'end': {'year': '2025', 'month': '02', 'day': '25'}}, -: {'type': 'special_case', 'value': '-'}, 전북특별자치도 청년정책과:{'전북'}, □ 부모와 따로 거주하는 무주택 청년(19~34세) 중 보증부월세 거주(청약통장가입자)
# ※ (신청일 기준) 임대차 계약을 맺은 건물(진안군 소재)에 주민등록이 등재되어 있어야 함.:{('전북', '전라북도')}임차보증금 1억 5천만원 이하이면서 대출금 유) 건물pe': 'special_case', 'value': '-'}, 진안군 농촌활력과 청장년지원팀:{('전북', '전라북도')}, □ 진안군에 임대차계약을 맺고 거주하는 기준중위소득 150% 이하 무주택 청년 세대주로 아래 각 호의 요건을 모두 충족하는 자
# □ 미혼청년(만18 ∼ 39세):{('전북', '전라북도')}age': 39}, 2024년02월01일~2024년12월31일: {'type': 'A', 'start': {'year': '2024', 'month': '02', 'day': '01'}, 'end': {'year': '2024', 'month': '12', 'day': '31'}}, 2024.02~12: {'type': 'same_year_months', 'start': {'year': '2024', 'month': '02'}, 'end': {'year': '2024', 'month': '12'}}, 정읍시:{('전북', '전라북도')}, □ 신혼부부(정읍시 거주 무주택 혼인 7년이내/혼인신고일 기준)
#     - 기준중위소득 180퍼센트 이하인 본인 (배우자,자녀포함) 소유의 주택이 없는 다자녀가구:{('전북', '전라북도')}lue': '상시'}, -: {'type': 'special_case', 'value': '-'}, 완주군:{('전북', '전라북도')}, □ 지원대상 : 신청일 기준 아래 조건을 모두 충족한 자
# ※ 이사비 지원액 예산 초과 시, 접수 완료 순으로 선착순 지급:{('충남', '충청남도')}득판정’기준표상 기준 중위소득 180% 이하alue': '상시'}, __: None, 광주시 청년지원센터(☎ 031-8027-0371):{'광주'}, ❍ 소득기준
# 만 19세 ~ 39세: {'min_age': 19, 'max_age': 39}, 상시: {'type': 'special_case', 'value': '상시'}, 2024.1.~12.: {'type': 'same_year_months', 'start': {'year': '2024', 'month': '1'}, 'end': {'year': '2024', 'month': '12'}}, 인천광역시 연수구 공간정보과:{'인천'}, 연수구 청년 누구나:{'인천'}
# □ 소득기준 : (원가구) 기준 중위소득 100% 이하 & (청년독립가구) 기준 중위소득 60% 이하:{('전북', '전라북도')}ype': 'A', 'start': {'year': '2024', 'month': '02', 'day': '26'}, 'end': {'year': '2025', 'month': '02', 'day': '25'}}, __: None, -:{'전국'}, □ 지원대상 : 만 19~34세 이하 부모님과 별도 거주 무주택 청년(청약통장 가입 필수)
# 제한없음: {'min_age': 0, 'max_age': None}, 2024년07월01일~2024년12월31일: {'type': 'A', 'start': {'year': '2024', 'month': '07', 'day': '01'}, 'end': {'year': '2024', 'month': '12', 'day': '31'}}, 2024.6.~2024.12.: {'type': 'year_month', 'start': {'year': '2024', 'month': '6'}, 'end': {'year': '2024', 'month': '12'}}, 충주시 기획예산과 청년인구정책팀:{('충북', '충청북도')}, 주거 자금(구입, 전세) 목적으로 금융권 대출을 실행한 충주시 거주 혼인 7년 이내 청년 신혼부부 - 지원대상 세부 자격 공고문 확인:{('충북', '충청북도')}
# 제한없음: {'min_age': 0, 'max_age': None}, 상시: {'type': 'special_case', 'value': '상시'}, 2024.1~2024.12: {'type': 'year_month', 'start': {'year': '2024', 'month': '1'}, 'end': {'year': '2024', 'month': '12'}}, 충청북도 과학인재국 RISE추진과 지산학협력팀:{'충북'}, 본인 또는 친권자(후견자)의 주소가 충청북도인 자 - (서/동서울관) 수도권 지역 대학의 신입생 또는 재학생 - (청 주 관) 도내 대학(원)의 신입생 또는 재학생:{'서울'}
# 만 19세 ~ 34세: {'min_age': 19, 'max_age': 34}, 상시: {'type': 'special_case', 'value': '상시'}, 2024.1월~2024.12월: {'type': 'year_month', 'start': {'year': '2024', 'month': '1'}, 'end': {'year': '2024', 'month': '12'}}, 충청북도기획관리실 인구청년정책담당관 청년지원팀:{'충북'}, 도내 거주 19세 ~ 34세 이하 부모님과 별도거주 무주택 청년 (청약통장 가입 필수) - 소득요건 : 원가구 중위소득 100%이하+청년가구 중위소득 60%이하:{('전북', '전라북도')}
# 제한없음: {'min_age': 0, 'max_age': None}, 2024년01월01일~2024년12월31일: {'type': 'A', 'start': {'year': '2024', 'month': '01', 'day': '01'}, 'end': {'year': '2024', 'month': '12', 'day': '31'}}, 2024.01.01.~2024.12.31.: {'type': 'full_date', 'start': {'year': '2024', 'month': '01', 'day': '01'}, 'end': {'year': '2024', 'month': '12', 'day': '31'}}, 광주광역시 도시공간국 주택정책과:{'광주'}, -:{'전국'}
# 만 19세 ~ 34세: {'min_age': 19, 'max_age': 34}, 상시: {'type': 'special_case', 'value': '상시'}, -: {'type': 'special_case', 'value': '-'}, 대한적십자사:{'전국'}, 퇴소했거나 재원중이거나 보호가 종료된 아동(만18세~34세) 1,000명:{'전국'}
#  (일반형) 부부합산 연소득 5천만원 이하자 중 우대형에 해당하지 아니한 자:{('전북', '전라북도')}세대주로 인정되는자 포함)인 자불가능중 소득 3분위 전체가구 평균값 이하(십만원 단위에서 반올림)인 자 요건을 모두 충족하는 자
#
# === 추천 정책 1 ===
# 제목: 대전 전세사기피해자 지원
# ※ 당해년도 예산이 소진되어 신청하신 지원금은 2025년도에 지급될 예정입니다.
# 연령: 제한없음
# 신청: 상시
# 기관: 대전 전세피해지원센터
# ❍ 지원요건 : 전세사기피해자 결정일 현재 ① 임대차계약을 체결한 피해주택의 소재지가 대전시이고, ② 대전시에 주민등록을 두고 거주하는 자
# 상세 정보: https://www.youthcenter.go.kr/youngPlcyUnif/youngPlcyUnifDtl.do?bizId=R2024112027984
#
# === 추천 정책 2 ===
# 제목: 청년월세 한시 특별지원
# 설명: 고금리·고물가 등으로 경제적 어려움을 겪는 청년층의 주거비 부담 경감을 위해 청년월세를 한시적으로 지원합니다.
# 연령: 만 19세 ~ 34세
# 신청: 상시
# 기관: 국토교통부
# ○ (원가구) 청년독립가구 + 1촌이내 직계혈족(부·모)소지에 거주하는 그 외「민법」상 가족소득 50% 이상으로 생계를 달리한다고 시·군·구청장이 인정하는 경우 등은 원가구 소득 미고려
# 상세 정보: https://www.youthcenter.go.kr/youngPlcyUnif/youngPlcyUnifDtl.do?bizId=R2024101827203
#
# === 추천 정책 3 ===
# 제목: 미혼청년 주거급여 분리지급
# 설명: 21년도부터 수급가구 내 부모와 떨어져 사는 청년 대상에게 주거급여를 별도로 지급
# 연령: 제한없음
# 신청: 상시
# 기관: 국토교통부
# ※ 보장기관이 인정하는 경우 예외 가능주민등록상 시·군을 달리하는 경우 인정미만의 미혼자녀
# 상세 정보: https://www.youthcenter.go.kr/youngPlcyUnif/youngPlcyUnifDtl.do?bizId=R2024092626737
#
# === 추천 정책 4 ===
# 제목: 청년행복주택(청년을 위한 공적임대주택 공급)
# 설명: 청년들의 주거복지 실현을 위해 청년공공임대주택(청년행복주택) 사업 및 청년 공공지원 민간주택임대 사업 실시
# 연령: 만 19세 ~ 39세
# 신청: 상시
# 기관: 국토교통부 민간임대정책과
# 지역: *입주자 모집공고 확인
# 상세 정보: https://www.youthcenter.go.kr/youngPlcyUnif/youngPlcyUnifDtl.do?bizId=R2024081325984
#
# === 추천 정책 5 ===
# 제목: 울산 신정동 청년희망주택 건립사업
# 설명: 청년가구 주거만족도가 높은 선호지(시소유)에 특화된 설계로 건립하여 청년가구 주거 만족도 향상
# 연령: 만 18세 ~ 39세
# 신청: 상시
# 기관: 울산광역시 건축정책과 주거지원팀(052-229-4412)
# 지역: -
# 상세 정보: https://www.youthcenter.go.kr/youngPlcyUnif/youngPlcyUnifDtl.do?bizId=R2024073125575
#
# === 추천 정책 6 ===
# 제목: 울산 매곡산업단지 복합개발사업
# 설명: 산업단지 근로자의 주거불안 해소와 청년 창업을 연계할 수 있는 공공 임대주택을 공급하여 주거안정 및 일자리 창출
# 연령: 만 18세 ~ 39세
# 신청: 상시
# 기관: 울산광역시 건축정책과 주거지원팀(052-229-4414)
# 지역: -
# 상세 정보: https://www.youthcenter.go.kr/youngPlcyUnif/youngPlcyUnifDtl.do?bizId=R2024073125574
#
# === 추천 정책 7 ===
# 제목: 울산 신축 매입약정형 임대주택 공급사업
# 설명: 청년·신혼부부의 주거비 부담해소를 위해 신속한 공공주택 공급 방안인 신축 매입약정형 임대주택 사업을 도입하여 주거안정 도모
# 연령: 만 18세 ~ 39세
# 신청: 상시
# 기관: 울산광역시 건축정책과 주거지원팀(052-229-4413)
# 지역: -
# 상세 정보: https://www.youthcenter.go.kr/youngPlcyUnif/youngPlcyUnifDtl.do?bizId=R2024073125573
#
# === 추천 정책 8 ===
# 제목: 울산 양정동 청년희망주택 건립사업
# 설명: 청년가구 주거만족도가 높은 선호지(시소유)에 특화된 설계로 건립하여 청년가구 주거 만족도 향상
# 연령: 만 19세 ~ 39세
# 신청: 상시
# 기관: 울산광역시 건축정책과 주거지원팀(052-229-4412)
# 지역: -
# 상세 정보: https://www.youthcenter.go.kr/youngPlcyUnif/youngPlcyUnifDtl.do?bizId=R2024073125572
#
# === 추천 정책 9 ===
# 제목: 울산 방어동 청년희망주택 건립사업
# 설명: 청년가구 주거만족도가 높은 선호지(시소유)에 특화된 설계로 건립하여 청년가구 주거 만족도 향상
# 연령: 만 18세 ~ 39세
# 신청: 상시
# 기관: 울산광역시 건축정책과 주거지원팀(052-229-4412)
# 지역: -
# 상세 정보: https://www.youthcenter.go.kr/youngPlcyUnif/youngPlcyUnifDtl.do?bizId=R2024073125571
#
# === 추천 정책 10 ===
# 제목: 울산 백합 청년희망주택 건립사업
# 설명: 청년가구 주거만족도가 높은 선호지(시소유)에 특화된 설계 건립하여 청년가구 주거 만족도 향상
# 연령: 만 18세 ~ 39세
# 신청: 상시
# 기관: 울산광역시 건축정책과 주거지원팀(052-229-4412)
# 지역: -
# 상세 정보: https://www.youthcenter.go.kr/youngPlcyUnif/youngPlcyUnifDtl.do?bizId=R2024073125570
#
# === 추천 정책 11 ===
# 제목: 울산 달동 청년희망주택 건립사업
# 설명: 청년가구 주거만족도가 높은 선호지(시소유)에 특화된 설계로 건립하여 청년가구 주거 만족도 향상
# 연령: 만 18세 ~ 39세
# 신청: 상시
# 기관: 울산광역시 건축정책과 주거지원팀 (052-229-4412)
# 지역: -
# 상세 정보: https://www.youthcenter.go.kr/youngPlcyUnif/youngPlcyUnifDtl.do?bizId=R2024073125569
#
# === 추천 정책 12 ===
# 제목: 울산 삼산동 청년희망주택 건립사업
# 설명: 청년가구 주거만족도가 높은 선호지(시소유)에 특화된 설계로 건립하여 청년가구 주거 만족도 향상
# 연령: 만 18세 ~ 39세
# 신청: 상시
# 기관: 울산광역시 건축정책과 주거지원팀(052-229-4412)
# 지역: -
# 상세 정보: https://www.youthcenter.go.kr/youngPlcyUnif/youngPlcyUnifDtl.do?bizId=R2024073125568
#
# === 추천 정책 13 ===
# 제목: 울산 태화동 청년희망주택 건립사업
# 설명: 청년가구 주거만족도가 높은 선호지(시소유)에 특화된 설계로 건립하여 청년가구 주거 만족도 향상
# 연령: 만 18세 ~ 39세
# 신청: 상시
# 기관: 울산광역시 건축정책과 주거지원팀 (052-229-4412)
# 지역: -
# 상세 정보: https://www.youthcenter.go.kr/youngPlcyUnif/youngPlcyUnifDtl.do?bizId=R2024073125567
#
# === 추천 정책 14 ===
# 제목: 울산 상안지구 행복주택 건립
# 설명: 사회초년생, 신혼부부 등 청년층의 주거안정 도모 / 청년층의 주거안정을 위한 저렴한 공공임대주택 공급 확대
# 연령: 제한없음
# 신청: 상시
# 기관: 울산도시공사 주택사업팀(052-219-8457)
# 지역: -
# 상세 정보: https://www.youthcenter.go.kr/youngPlcyUnif/youngPlcyUnifDtl.do?bizId=R2024073125565
#
# === 추천 정책 15 ===
# 제목: 울산 북구 매곡산업단지 내 행복주택 공급 지원
# 설명: 산업단지 근로자의 주거불안 해소와 청년 창업을연계할 수 있는 공공임대 주택을 공급하여 주거안정 및 일자리 창출로 인한 인구 유입
# 연령: 만 19세 ~ 39세
# 신청: 상시
# 기관: 울산광역시 북구 건축정책과 주택허가팀(052-214-8022)
# 지역: -
# 상세 정보: https://www.youthcenter.go.kr/youngPlcyUnif/youngPlcyUnifDtl.do?bizId=R2024072325335
#
# === 추천 정책 16 ===
# 제목: 울산 북구 상안지구 행복주택 공급 지원
# 설명: 사회초년생 및 신혼부부 등 청년층의 주거안정을 도모하며, 청년층의 주거안정을 위한 저렴한 공공임대주택의 공급을 확대하고자 함
# 연령: 만 19세 ~ 39세
# 신청: 상시
# 기관: 울산광역시 북구 건축정책과 주택허가팀(052-241-8022)
# 지역: -
# 상세 정보: https://www.youthcenter.go.kr/youngPlcyUnif/youngPlcyUnifDtl.do?bizId=R2024072325336
#
# === 추천 정책 17 ===
# 제목: 울산 울주군 청년월세 한시 특별지원
# 설명: 경제적으로 어려움을 겪고 있는 청년층의 주거비 부담 경감을 위해 청년 임차인이 납부한 월세를 최대 20만원까지 지원하는 사업
# 연령: 만 19세 ~ 34세
# 신청: 2024년 02월  26일 ~
# 								2025년 02월  25일
# 기관: 국토교통부 (민원 콜센터 : 1600-0777)
# ** 준주택 : 기숙사, 고시원, 오피스텔 등다세대주택 등”, 그 외 거주를 목적으로 하는 시설, 임차보증금과 월세 제한 없음
# 상세 정보: https://www.youthcenter.go.kr/youngPlcyUnif/youngPlcyUnifDtl.do?bizId=R2024061223885
#
# === 추천 정책 18 ===
# 제목: 울산 남구 청년월세 한시 특별지원
# 설명: 경제적으로 어려움을 겪고 있는 청년층의 주거비 부담 경감을 위해 청년 임차인이 납부한 월세를 최대 20만원까지 지원하는 사업
# 연령: 만 19세 ~ 34세
# 신청: 2024년 02월  26일 ~
# 								2025년 02월  25일
# 기관: 국토교통부 (민원 콜센터 : 1600-0777)
# ** 준주택 : 기숙사, 고시원, 오피스텔 등다세대주택 등”, 그 외 거주를 목적으로 하는 시설, 임차보증금과 월세 제한 없음
# 상세 정보: https://www.youthcenter.go.kr/youngPlcyUnif/youngPlcyUnifDtl.do?bizId=R2024061223867
#
# === 추천 정책 19 ===
# 제목: 울산 동구 청년월세 한시 특별지원
# 설명: 경제적으로 어려움을 겪고 있는 청년층의 주거비 부담 경감을 위해 청년 임차인이 납부한 월세를 최대 20만원까지 지원하는 사업
# 연령: 만 19세 ~ 34세
# 신청: 2024년 02월  26일 ~
# 								2025년 02월  25일
# 기관: 국토교통부 (민원 콜센터 : 1600-0777)
# ** 준주택 : 기숙사, 고시원, 오피스텔 등다세대주택 등”, 그 외 거주를 목적으로 하는 시설, 임차보증금과 월세 제한 없음
# 상세 정보: https://www.youthcenter.go.kr/youngPlcyUnif/youngPlcyUnifDtl.do?bizId=R2024061223883
#
# === 추천 정책 20 ===
# 제목: 울산 중구 청년월세 한시 특별지원
# 설명: 경제적으로 어려움을 겪고 있는 청년층의 주거비 부담 경감을 위해 청년 임차인이 납부한 월세를 최대 20만원까지 지원하는 사업
# 연령: 만 19세 ~ 34세
# 신청: 2024년 02월  26일 ~
# 								2025년 02월  25일
# 기관: 국토교통부 (민원 콜센터 : 1600-0777)
# ** 준주택 : 기숙사, 고시원, 오피스텔 등다세대주택 등”, 그 외 거주를 목적으로 하는 시설, 임차보증금과 월세 제한 없음
# 상세 정보: https://www.youthcenter.go.kr/youngPlcyUnif/youngPlcyUnifDtl.do?bizId=R2024061223866
#
# === 추천 정책 21 ===
# 제목: 울산 북구 청년월세 한시 특별지원
# 설명: 경제적으로 어려움을 겪고 있는 청년층의 주거비 부담 경감을 위해 청년 임차인이 납부한 월세를 최대 20만원까지 지원하는 사업
# 연령: 만 19세 ~ 34세
# 신청: 2024년 02월  26일 ~
# 								2025년 02월  25일
# 기관: 국토교통부 (민원 콜센터 : 1600-0777)
# ** 준주택 : 기숙사, 고시원, 오피스텔 등다세대주택 등”, 그 외 거주를 목적으로 하는 시설, 임차보증금과 월세 제한 없음
# 상세 정보: https://www.youthcenter.go.kr/youngPlcyUnif/youngPlcyUnifDtl.do?bizId=R2024061223865
#
# === 추천 정책 22 ===
# 제목: 김해시 민간참여형 청년주택 입주자 및 예비입주자 모집
# 설명: 청년계층 1인 가구의 주거난 해소와 주거비 절감을 위해 운영하는 민간참여형 청년주택
# 연령: 만 19세 ~ 39세
# 신청: 상시
# 기관: 김해시청 공동주택과 저소득주거지원팀(☎ 055-330-4318)
# 지역: □ 신청대상 : 입주자 모집 공고일(2024. 5. 30.) 현재 만19세 이상 만39세 이하의 청년으로 전년도 도시근로자 월평균소득의 120% (4,179,557원)이하인 자
# 상세 정보: https://www.youthcenter.go.kr/youngPlcyUnif/youngPlcyUnifDtl.do?bizId=R2024060523764
#
# === 추천 정책 23 ===
# 제목: 주택 연세 · 월세 대출이자 지원
# 설명: 무주택·자녀출산 가정 및 사회초년생에 대한 연·월세 자금 및 대출이자 지원을 통해 주거약자의 주거비 부담을 완화하고 무주택 서민의 주거 안정을 도모
# 연령: 만 19세 ~ 39세
# 신청: 미정
# 기관: 제주특별자치도 / 주택토지과(주거복지팀)
# 지역: None
# 상세 정보: https://www.youthcenter.go.kr/youngPlcyUnif/youngPlcyUnifDtl.do?bizId=R2024042222071
#
# === 추천 정책 24 ===
# 제목: 청년안심주택 공급(매입)
# 설명: 역세권(간선도로변)의 민간소유 토지를 체계적으로 개발(민간 주도+공공 지원)하여 쾌적하고 저렴한 주택을 공급함으로써 청년층의 주거안정을 도모하고 지역경제를 활성화하고자 함.
# 연령: 만 19세 ~ 39세
# 신청: 상시
# 기관: 전략주택공급과
# 지역: -
# 상세 정보: https://www.youthcenter.go.kr/youngPlcyUnif/youngPlcyUnifDtl.do?bizId=R2024051022688
#
# === 추천 정책 25 ===
# 제목: 신혼부부 청년 임차보증금 지원사업
# 설명: 청년과 신혼부부의 주거비부담을 경감하여 혼인 감소 및 출산율 감소문제를 해결하기 위해 임차보증금 대출을 지원하여 주거디딤돌 역할
# 연령: 제한없음
# 신청: 상시
# 기관: 주택정책과
# ※ 2024년 3월 1일 이후 접수자부터 아래의 신청자격 기준 적용 소득 및 자산 기준을 충족하는 자
# 상세 정보: https://www.youthcenter.go.kr/youngPlcyUnif/youngPlcyUnifDtl.do?bizId=R2024051022712
#
# === 추천 정책 26 ===
# 제목: 청년 전월세 보증금대출이자 지원
# 설명: □ 경제적으로 어려움을 겪는 청년의 주거 안정과 정착 여건을 향상시키기 위하여 전·월세 보증금 및 주택구입을 위한 대출이자를 지원
# 연령: 만 18세 ~ 45세
# 신청: 상시
# 기관: □ 예산군
#   ※ 45세 이하기준, 군에 주민등록이 되어있는 18세 ~ 45세 이하의 세대주 청년 또는 혼인신고일 기준 5년 미만인 신혼부부
# 상세 정보: https://www.youthcenter.go.kr/youngPlcyUnif/youngPlcyUnifDtl.do?bizId=R2024042922344
#
# === 추천 정책 27 ===
# 제목: 청년 월세 특별지원 사업(대구)
# 설명: 경제적 어려움을 겪는 청년층의 주거비 부담을 덜어드리기 위해 12개월 분의 월세를 월 최대 20만원까지 지원하는 사업
# 연령: 만 19세 ~ 34세
# 신청: 2024년 02월  26일 ~
# 								2025년 02월  25일
# 기관: □ 국토교통부
#   ※ 원가구 : 청년가구+1촌이내 직계혈족(부모)소지 거주중 민법상 가족이하
# 상세 정보: https://www.youthcenter.go.kr/youngPlcyUnif/youngPlcyUnifDtl.do?bizId=R2024042322180
#
# === 추천 정책 28 ===
# 제목: 전입대학생 기숙사비 지원
# 설명: □ 안정적 주거지원
# 연령: 만 25세 ~ 35세
# 신청: 상시
# 기관: □ 청양군
# 지역: □ 다른 시‧군‧구에서 전입일을 기준으로 1년이상 주소를 두고 있다가 군 내에 전입한 자
# 상세 정보: https://www.youthcenter.go.kr/youngPlcyUnif/youngPlcyUnifDtl.do?bizId=R2024042222114
#
# === 추천 정책 29 ===
# 제목: 청년월세 한시 특별지원 2차 사업(칠곡군)
# 설명: 청년 주거비 지원
# 연령: 만 19세 ~ 34세
# 신청: 2024년 02월  26일 ~
# 								2025년 02월  25일
# 기관: 국토교통부
# 지역: □ 대상자 : ⌜청년기본법⌟상 청년(만 19~34세 이하)으로 부모님과 별도 거주하는 무주택자
# 상세 정보: https://www.youthcenter.go.kr/youngPlcyUnif/youngPlcyUnifDtl.do?bizId=R2024042222072
#
# === 추천 정책 30 ===
# 제목: 청년 임대료 지원
# 설명: □ 경제적으로 어려움을 겪는 청년들의 주거비 부담을 덜어주기위한 청년 임대료 지원
# 연령: 만 18세 ~ 45세
# 신청: 상시
# 기관: □ 예산군 총무과
# -건강보험증(사본) *건강보험 자격확인(통보)서 대체 가능
# 상세 정보: https://www.youthcenter.go.kr/youngPlcyUnif/youngPlcyUnifDtl.do?bizId=R2024042222046
#
# === 추천 정책 31 ===
# 제목: 청년월세 한시 특별지원사업 2차 모집 안내
# 설명: 청년의 주거비 부담 감소 및 안정적 주거생활 지원
# 연령: 만 19세 ~ 34세
# 신청: 2024년 02월  26일 ~
# 								2025년 02월  25일
# 기관: 국토교통부
# ○ (원가구) 기준중위소득 100%이하&(청년독립가구) 기준 중위소득 60%이하 거주 무주택 청년(청약저축 가입자)
# 상세 정보: https://www.youthcenter.go.kr/youngPlcyUnif/youngPlcyUnifDtl.do?bizId=R2024041922025
#
# === 추천 정책 32 ===
# 제목: 주택 연세 · 월세 대출
# 설명: 무주택·자녀출산 가정 및 사회초년생에 대한 연·월세 자금 및 대출이자 지원을 통해 주거약자의 주거비 부담을 완화하고 무주택 서민의 주거 안정을 도모
# 연령: 만 19세 ~ 39세
# 신청: 상시
# 기관: 제주특별자치도 / 주택토지과(주거복지팀)
# 지역: None
# 상세 정보: https://www.youthcenter.go.kr/youngPlcyUnif/youngPlcyUnifDtl.do?bizId=R2024041922005
#
# === 추천 정책 33 ===
# 제목: 청년월세 한시 특별지원 사업(영주시)
# 설명: 경제적 어려움을 겪고 있는 청년층의 주거비 부담 경감을 위해 청년월세를 한시적으로 지원
# 연령: 만 19세 ~ 34세
# 신청: 2024년 02월  26일 ~
# 								2025년 02월  25일
# 기관: 국토교통부
# ❍ 지원자격 : 청년가구 소득 기준 중위소득 60% 이하, 원가구 소득 기준 중위소득 100% 이하
# 상세 정보: https://www.youthcenter.go.kr/youngPlcyUnif/youngPlcyUnifDtl.do?bizId=R2024041721880
#
# === 추천 정책 34 ===
# 제목: 청년 주거 임차비 지원
# 설명: 청년 창업 지원사업 등에 참여한 청년에게 주거 임차비 지원
# 연령: 만 19세 ~ 45세
# 신청: 상시
# 기관: 상주시
# 지역: -
# 상세 정보: https://www.youthcenter.go.kr/youngPlcyUnif/youngPlcyUnifDtl.do?bizId=R2024041121671
#
# === 추천 정책 35 ===
# 제목: 청년월세 한시 특별지원사업
# 설명: □ 청년들의 주거비 경감
# 연령: 만 19세 ~ 34세
# 신청: 2024년 02월  01일 ~
# 								2025년 02월  31일
# 기관: □ 국토교통부
#  ※ 거주하는 본인 또는 시민 자녀둔자
# 상세 정보: https://www.youthcenter.go.kr/youngPlcyUnif/youngPlcyUnifDtl.do?bizId=R2024040821505
#
# === 추천 정책 36 ===
# 제목: 2024년 청년 월세 주거비 지원사업
# 설명: 최대 10개월 간 1인 월 최대 10만원 지원
# 연령: 만 18세 ~ 45세
# 신청: 미정
# 기관: 고령군
# 지역: -
# 상세 정보: https://www.youthcenter.go.kr/youngPlcyUnif/youngPlcyUnifDtl.do?bizId=R2024040421428
#
# === 추천 정책 37 ===
# 제목: 서울시 청년안심주택(공공지원민간임대) 임대보증금 지원
# 설명: 대중교통이 편리한 역세권 및 간선도로변에 청년, 신혼부부의 주거안정 및 주거난 해소를 위해 시세대비 저렴한 공공임대와 민간임대 주택을 제공
# 연령: 만 19세 ~ 39세
# 신청: 상시
# 기관: 서울시청 전략주택공급과
#    - 신혼부부 : 신혼부부 및 자녀 합산 자산 기준 3억 4,500만원 이하수별 가구당 월평균 소득 120%이하(2인가구:6,498,854원 / 3인가구:8.638.379원)
# 상세 정보: https://www.youthcenter.go.kr/youngPlcyUnif/youngPlcyUnifDtl.do?bizId=R2024031920824
#
# === 추천 정책 38 ===
# 제목: 청년월세 한시 특별지원 2차
# 설명: 청년이 직면하는 높은 주거비 부담을 경감하여 주거안정 도모
# 연령: 만 19세 ~ 34세
# 신청: 2024년 02월  26일 ~
# 								2025년 02월  25일
# 기관: -
# □ 소득기준 : (원가구) 기준 중위소득 100% 이하 & (청년독립가구) 기준 중위소득 60% 이하
# 상세 정보: https://www.youthcenter.go.kr/youngPlcyUnif/youngPlcyUnifDtl.do?bizId=R2024021919780
#
# === 추천 정책 39 ===
# 제목: 유스타트 주택청약 종합저축 지원사업
# 설명: 자립준비청년의 주거 복지를 위한 주택청약종합저축 납입지원금 지원
# 연령: 만 19세 ~ 34세
# 신청: 상시
# 기관: 대한적십자사
# 지역: 퇴소했거나 재원중이거나 보호가 종료된 아동(만18세~34세) 1,000명
# 상세 정보: https://www.youthcenter.go.kr/youngPlcyUnif/youngPlcyUnifDtl.do?bizId=R2024011718953
#
# === 추천 정책 40 ===
# 제목: 주거안정월세대출
# 설명: 월세 부담으로 고민인 청년들에게 청년전용 주거안정 월세자금 대출
# 연령: 제한없음
# 신청: 상시
# 기관: 국토교통부 주택기금과
#  (일반형) 부부합산 연소득 5천만원 이하자 중 우대형에 해당하지 아니한 자로 인정되는 자 포함)인 자주(세대주로 인정되는자 포함)인 자불가능중 소득 3분위 전체가구 평균값 이하(십만원 단위에서 반올림)인 자
# 상세 정보: https://www.youthcenter.go.kr/youngPlcyUnif/youngPlcyUnifDtl.do?bizId=R2024010918590

# %%
import re

date_patterns = {
    # Basic patterns
    'full_date_dots': r'(\d{4})\.(\d{1,2})\.(\d{1,2})\.?\s*~\s*(\d{4})\.(\d{1,2})\.(\d{1,2})\.?',
    'year_month_dots': r'(\d{4})\.\s*(\d{1,2})\.\s*~\s*(\d{4})\.\s*(\d{1,2})\.',
    'full_date_hyphens': r'(\d{4})-(\d{1,2})-(\d{1,2})\s*~\s*(\d{4})-(\d{1,2})-(\d{1,2})',
    'same_year_months': r'(\d{4})\.\s*(\d{1,2})\.\s*~\s*(\d{1,2})\.',
    'years_only': r'(\d{4})\.\s*~\s*(\d{4})\.',
    'year_month_minimal': r'(\d{4})\.(\d{1,2})\s*~\s*(\d{4})\.(\d{1,2})',
    
    # Korean specific patterns
    'korean_year_month': r'(\d{4})년\s*(\d{1,2})월\s*~\s*(\d{4})년\s*(\d{1,2})월',
    'korean_year_month_single': r'(\d{4})년\s*(\d{1,2})월',
    'korean_full_date': r'(\d{4})년\s*(\d{1,2})월\s*(\d{1,2})일\s*~\s*(\d{4})년\s*(\d{1,2})월\s*(\d{1,2})일',
    
    # Special formats
    'year_month_range': r'(\d{4})\.(\d{1,2})월?\s*~\s*(\d{1,2})월?',
    'bullet_year_month': r'[•○□]\s*(\d{4})\.(\d{1,2})\.\s*~\s*(\d{4})\.(\d{1,2})\.',
    'short_year_format': r"'(\d{2})\.(\d{1,2})\.\s*~\s*'?(\d{2})\.(\d{1,2})\.",
    
    # Additional patterns for your specific cases
    'year_month_note': r'(\d{4})\.(\d{1,2})\.\s*~\s*(\d{4})\.(\d{1,2})\.\s*\(※[^)]+\)',
    'bullet_year_month_simple': r'[•○□]\s*(\d{4})\.(\d{1,2})\.\s*~\s*(\d{1,2})\.',
    'bullet_full_year_month': r'[□○•]\s*(\d{4})\.(\d{1,2})\.\s*~\s*(\d{4})\.(\d{1,2})',  # □2024.3.~2024.12 패턴
    'bullet_short_year_month': r'[□○•][사업|추진]기간:\s*\'(\d{2})\.(\d{1,2})\.\s*~\s*(\d{1,2})\.(?:\s*※.*)?',  # ○사업기간:'24.1.~12. 패턴
    
    # Special cases
    'special_cases': r'(연중|예산소진시까지|계속사업|현재|상시|미정|-)',
}

def parse_date_string(date_str):
    """
    Parse date string and extract start and end dates
    
    Args:
        date_str (str): Input date string
        
    Returns:
        dict: Parsed date information or special case string
    """
    # Clean input string
    date_str = date_str.strip()
    
    # Check special cases first
    special_match = re.search(date_patterns['special_cases'], date_str)
    if special_match:
        return {'type': 'special_case', 'value': special_match.group(1)}
    
    for pattern_name, pattern in date_patterns.items():
        if pattern_name == 'special_cases':
            continue
            
        match = re.search(pattern, date_str)
        if match:
            groups = match.groups()
            
            # Handle different patterns
            if pattern_name in ['bullet_year_month', 'year_month_dots', 'year_month_minimal']:
                return {
                    'type': 'year_month',
                    'start': {'year': groups[0], 'month': groups[1]},
                    'end': {'year': groups[2], 'month': groups[3]}
                }
            
            elif pattern_name == 'korean_year_month':
                return {
                    'type': 'year_month',
                    'start': {'year': groups[0], 'month': groups[1]},
                    'end': {'year': groups[2], 'month': groups[3]}
                }
            
            elif pattern_name == 'korean_full_date':
                return {
                    'type': 'full_date',
                    'start': {'year': groups[0], 'month': groups[1], 'day': groups[2]},
                    'end': {'year': groups[3], 'month': groups[4], 'day': groups[5]}
                }
            
            elif pattern_name == 'year_month_range':
                return {
                    'type': 'same_year_months',
                    'start': {'year': groups[0], 'month': groups[1]},
                    'end': {'year': groups[0], 'month': groups[2]}
                }
            
            elif pattern_name == 'short_year_format':
                start_year = '20' + groups[0]
                end_year = '20' + groups[2]
                return {
                    'type': 'year_month',
                    'start': {'year': start_year, 'month': groups[1]},
                    'end': {'year': end_year, 'month': groups[3]}
                }
            
            elif pattern_name == 'year_month_note':
                return {
                    'type': 'year_month_with_note',
                    'start': {'year': groups[0], 'month': groups[1]},
                    'end': {'year': groups[2], 'month': groups[3]}
                }
            
            elif pattern_name == 'bullet_year_month_simple':
                return {
                    'type': 'same_year_months',
                    'start': {'year': groups[0], 'month': groups[1]},
                    'end': {'year': groups[0], 'month': groups[2]}
                }
            elif pattern_name == 'bullet_full_year_month':
                return {
                    'type': 'year_month',
                    'start': {'year': groups[0], 'month': groups[1]},
                    'end': {'year': groups[2], 'month': groups[3]}
                }
            
            elif pattern_name == 'bullet_short_year_month':
                start_year = '20' + groups[0]
                return {
                    'type': 'same_year_months',
                    'start': {'year': start_year, 'month': groups[1]},
                    'end': {'year': start_year, 'month': groups[2]}
                }
                
    return None

# Test function
def test_parser():
    test_cases = [
        "•사업기간:'24.2.~'26.12.(※신청기간:'24.2.26.부터1년간)",
        "○추진기간:'24.1.~12.",
        "○사업기간:'24.1.~12.",
        "○사업기간:'24.1.~12.※2019년중구지회협약에따른연장",
        "□2024.3.~2024.12",
        "2024.02~12",
        "2024.1월~2024.12월"
    ]
    
    for test_case in test_cases:
        result = parse_date_string(test_case)
        print(f"Input: {test_case}")
        print(f"Result: {result}\n")
test_parser()
# Out:
# Input: •사업기간:'24.2.~'26.12.(※신청기간:'24.2.26.부터1년간)
# Result: {'type': 'year_month', 'start': {'year': '2024', 'month': '2'}, 'end': {'year': '2026', 'month': '12'}}
#
# Input: ○추진기간:'24.1.~12.
# Result: None
#
# Input: ○사업기간:'24.1.~12.
# Result: None
#
# Input: ○사업기간:'24.1.~12.※2019년중구지회협약에따른연장
# Result: None
#
# Input: □2024.3.~2024.12
# Result: {'type': 'year_month', 'start': {'year': '2024', 'month': '3'}, 'end': {'year': '2024', 'month': '12'}}
#
# Input: 2024.02~12
# Result: {'type': 'same_year_months', 'start': {'year': '2024', 'month': '02'}, 'end': {'year': '2024', 'month': '12'}}
#
# Input: 2024.1월~2024.12월
# Result: {'type': 'same_year_months', 'start': {'year': '2024', 'month': '1'}, 'end': {'year': '2024', 'month': '20'}}

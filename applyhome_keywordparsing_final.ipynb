# %% [markdown]
# # 청약 applyhome

# %% [markdown]
# # 1. Data processing

# %%
pwd
# Out:
# '/Users/hyottz/Desktop/24f-houseplan/24f_daiv_houseplan/data_processing'

# %%
# !pip install pdfplumber
# Out:
# Requirement already satisfied: pdfplumber in /Users/hyottz/anaconda3/envs/HAI/lib/python3.9/site-packages (0.11.5)
# Requirement already satisfied: pdfminer.six==20231228 in /Users/hyottz/anaconda3/envs/HAI/lib/python3.9/site-packages (from pdfplumber) (20231228)
# Requirement already satisfied: Pillow>=9.1 in /Users/hyottz/anaconda3/envs/HAI/lib/python3.9/site-packages (from pdfplumber) (11.0.0)
# Requirement already satisfied: pypdfium2>=4.18.0 in /Users/hyottz/anaconda3/envs/HAI/lib/python3.9/site-packages (from pdfplumber) (4.30.1)
# Requirement already satisfied: charset-normalizer>=2.0.0 in /Users/hyottz/anaconda3/envs/HAI/lib/python3.9/site-packages (from pdfminer.six==20231228->pdfplumber) (2.0.4)
# Requirement already satisfied: cryptography>=36.0.0 in /Users/hyottz/anaconda3/envs/HAI/lib/python3.9/site-packages (from pdfminer.six==20231228->pdfplumber) (43.0.3)
# Requirement already satisfied: cffi>=1.12 in /Users/hyottz/anaconda3/envs/HAI/lib/python3.9/site-packages (from cryptography>=36.0.0->pdfminer.six==20231228->pdfplumber) (1.17.1)
# Requirement already satisfied: pycparser in /Users/hyottz/anaconda3/envs/HAI/lib/python3.9/site-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six==20231228->pdfplumber) (2.21)

# %%
import os
import pdfplumber
import pandas as pd
import re
import random

# 현재 작업 디렉토리 확인
current_dir = "/Users/hyottz/Desktop/24f-houseplan/24f_daiv_houseplan"

# 상대 경로 설정
api_data_path = os.path.join(current_dir, "data/api_data")

# PDF에서 표를 추출하여 데이터프레임으로 변환하는 함수 (특정 키워드 필터링)
def extract_filtered_tables_from_pdf(pdf_path, keyword="공급금액"):
    try:
        tables = []
        with pdfplumber.open(pdf_path) as pdf:
            for page_number, page in enumerate(pdf.pages, start=1):
                page_tables = page.extract_tables()
                for table in page_tables:
                    df = pd.DataFrame(table[1:], columns=table[0])  # 첫 번째 행을 컬럼으로 설정
                    if any(keyword in str(cell) for row in table for cell in row):
                        tables.append(df)
        return tables
    except Exception as e:
        print(f"Error reading {pdf_path}: {e}")
        return []

# PDF 파일 읽기 함수
def read_pdf_files(directory_path):
    pdf_files = []
    for root, _, files in os.walk(directory_path):
        for file in files:
            if file.endswith(".pdf"):
                pdf_files.append(os.path.join(root, file))
    return pdf_files

# 텍스트 추출 함수
def extract_text_from_pdf(pdf_path):
    try:
        text = ""
        with pdfplumber.open(pdf_path) as pdf:
            for page in pdf.pages:
                text += page.extract_text() + "\n"
        return text.strip()
    except Exception as e:
        print(f"Error reading {pdf_path}: {e}")
        return None

# 메타데이터 추출 함수
def extract_metadata(text, max_supply_price):
    metadata = {
        "supply_name": None,
        "region_name": None,
        "application_schedule": None,
        "special_supply_conditions": [],
        "enter_day": None,
        "max_supply_price": max_supply_price
    }

    # 공급명 추출
    supply_name_match = re.search(r"입주자모집공고주요정보\s*(.+)", text)
    if supply_name_match:
        metadata["supply_name"] = supply_name_match.group(1).strip()

    # 지역명 추출
    region_name_match = re.search(r"공급위치\s*(.+)", text)
    if region_name_match:
        metadata["region_name"] = region_name_match.group(1).strip()

    # 청약일정 추출
    schedule_match = re.search(r"당첨자 발표일\s*(\d{4}-\d{2}-\d{2})", text)
    if schedule_match:
        metadata["application_schedule"] = schedule_match.group(1).strip()

    
    # 특별공급조건 추출
    special_conditions_keywords = ["다자녀", "신혼부", "생애최", "노부모", "신생아", "청년"]
    for keyword in special_conditions_keywords:
        if keyword in text:
            metadata["special_supply_conditions"].append(keyword)

    # 입주예정월 추출
    enter_day_match = re.search(r"입주예정월 :\s*(\d{4}\.\d{2})", text)
    if enter_day_match:
        metadata["enter_day"] = enter_day_match.group(1).strip()

    return metadata

# PDF 파일 가져오기
api_pdfs = read_pdf_files(api_data_path)

# API PDF 메타데이터 추출
api_metadata = []
if api_pdfs:
    for pdf_path in api_pdfs:
        print(f"Reading API PDF: {pdf_path}")
        text = extract_text_from_pdf(pdf_path)

        max_supply_price = None
        filtered_tables = extract_filtered_tables_from_pdf(pdf_path)
        for table in filtered_tables:
            string_values = table.stack().apply(lambda x: x if isinstance(x, str) else None).dropna()
            split_values = string_values.str.split(expand=True).stack()
            numeric_values = split_values.apply(lambda x: int(x.replace(",", "")) if x.replace(",", "").isdigit() else None).dropna()
            if not numeric_values.empty:
                max_supply_price = numeric_values.min()
                break

        if text:
            metadata = extract_metadata(text, max_supply_price)
            api_metadata.append(metadata)

# # 메타데이터 출력
# for i, metadata in enumerate(api_metadata):
#     print(f"\nMetadata {i+1}:")
#     for key, value in metadata.items():
#         print(f"{key}: {value}")
# Out:
# Reading API PDF: /Users/hyottz/Desktop/24f-houseplan/24f_daiv_houseplan/data/api_data/9.pdf
# Reading API PDF: /Users/hyottz/Desktop/24f-houseplan/24f_daiv_houseplan/data/api_data/8.pdf
# Reading API PDF: /Users/hyottz/Desktop/24f-houseplan/24f_daiv_houseplan/data/api_data/6.pdf
# Reading API PDF: /Users/hyottz/Desktop/24f-houseplan/24f_daiv_houseplan/data/api_data/7.pdf
# Reading API PDF: /Users/hyottz/Desktop/24f-houseplan/24f_daiv_houseplan/data/api_data/5.pdf
# Reading API PDF: /Users/hyottz/Desktop/24f-houseplan/24f_daiv_houseplan/data/api_data/4.pdf
# Reading API PDF: /Users/hyottz/Desktop/24f-houseplan/24f_daiv_houseplan/data/api_data/1.pdf
# Reading API PDF: /Users/hyottz/Desktop/24f-houseplan/24f_daiv_houseplan/data/api_data/3.pdf
# Reading API PDF: /Users/hyottz/Desktop/24f-houseplan/24f_daiv_houseplan/data/api_data/2.pdf
#
# Metadata 1:
# supply_name: 서대문 센트럴 아이파크(임의공급 8차)
# region_name: 서울특별시 서대문구 홍은동 11-111번지 일원
# application_schedule: 2025-01-10
# special_supply_conditions: []
# enter_day: 2025.06
# max_supply_price: None
#
# Metadata 2:
# supply_name: 판교밸리자이 3단지 오피스텔
# region_name: 경기도 성남시 수정구 대왕판교로 961
# application_schedule: 2025-01-10
# special_supply_conditions: []
# enter_day: None
# max_supply_price: 95600.0
#
# Metadata 3:
# supply_name: 천안 두정역 양우내안애 퍼스트로
# region_name: 충청남도 천안시 서북구 두정동 393-11번지 일원
# application_schedule: 2025-01-13
# special_supply_conditions: ['다자녀', '신혼부', '생애최', '노부모', '신생아', '청년']
# enter_day: 2027.12
# max_supply_price: 39000
#
# Metadata 4:
# supply_name: 상월곡역 장위아트포레(도시형생활주택)
# region_name: 서울특별시 성북구 석관동 338-18
# application_schedule: 2025-01-13
# special_supply_conditions: []
# enter_day: None
# max_supply_price: 22500.0
#
# Metadata 5:
# supply_name: 부산에코델타시티 대방 엘리움 리버뷰
# region_name: 부산광역시 강서구 에코델타시티 공동주택용지 31BL
# application_schedule: 2025-01-16
# special_supply_conditions: ['다자녀', '신혼부', '생애최', '노부모', '신생아', '청년']
# enter_day: 2027.10
# max_supply_price: 108847
#
# Metadata 6:
# supply_name: 인천강화서희스타힐스 1단지(조합원 취소세대)
# region_name: 인천광역시 강화군 선원면 창리456번지 일원
# application_schedule: 2025-01-17
# special_supply_conditions: ['다자녀', '신혼부', '생애최', '노부모', '신생아', '청년']
# enter_day: 2025.02
# max_supply_price: 37574
#
# Metadata 7:
# supply_name: 성남금토 A-4블록 신혼희망타운(공공분양)(본청약)
# region_name: 경기도 성남시 수정구 금토동 일원 성남금토 공공주택지구 내 A-4블록
# application_schedule: 2025-01-24
# special_supply_conditions: ['다자녀', '신혼부', '생애최']
# enter_day: 2027.11
# max_supply_price: 62674
#
# Metadata 8:
# supply_name: 의왕청계2 A1블록 신혼희망타운(공공분양)(본청약)
# region_name: 경기도 의왕시 청계동, 포일동 일원 의왕청계2 공공주택지구 내 A1블록
# application_schedule: 2025-01-24
# special_supply_conditions: ['다자녀', '신혼부', '생애최']
# enter_day: 2028.04
# max_supply_price: 58732
#
# Metadata 9:
# supply_name: 더 팰리스트 데시앙
# region_name: 대구광역시 동구 신천동 481-1번지 외 16필지
# application_schedule: 2025-01-21
# special_supply_conditions: ['다자녀', '신혼부', '생애최', '노부모', '신생아', '청년']
# enter_day: 2025.10
# max_supply_price: 87870

# %%
import os
import pdfplumber
import re

# 현재 작업 디렉토리 확인
current_dir = "/Users/hyottz/Desktop/24f-houseplan/24f_daiv_houseplan"

# 상대 경로 설정
crawl_data_path = os.path.join(current_dir, "data/crawl_data")

# PDF 파일 읽기 함수
def read_pdf_files(directory_path):
    pdf_files = []
    for root, _, files in os.walk(directory_path):
        for file in files:
            if file.endswith(".pdf"):
                pdf_files.append(os.path.join(root, file))
    return pdf_files

# 텍스트 추출 함수
def extract_text_from_pdf(pdf_path):
    try:
        text = ""
        with pdfplumber.open(pdf_path) as pdf:
            for page in pdf.pages:
                text += page.extract_text() + "\n"
        return text.strip()
    except Exception as e:
        print(f"Error reading {pdf_path}: {e}")
        return None

# 메타데이터 추출 함수
def extract_metadata(text):
    metadata = {
        "supply_name": None,
        "region_name": None,
        "supply_type": None,
        "area": None,
        "application_schedule": None,
        "special_supply_conditions": []
    }

    # 공급명 추출
    supply_name_match = re.search(r"(.+?)\.pdf 바로보기", text)
    if supply_name_match:
        metadata["supply_name"] = supply_name_match.group(1).strip()

    # 지역명 추출
    region_name_match = re.search(r"모집지역\s*:\s*(.+?)$|소재지\s*:\s*(.+?)$", text, re.MULTILINE)
    if region_name_match:
        region_name = region_name_match.group(1) or region_name_match.group(2)
        if "확인" not in region_name:
            metadata["region_name"] = region_name.strip()

    # 공급유형 추출
    supply_type_match = re.search(r"유형\s*:\s*(.+?)\s", text)
    if supply_type_match:
        metadata["supply_type"] = supply_type_match.group(1).strip()

    # 면적 추출
    area_match = re.search(r"전용면적\(㎡\)\s*:\s*(\d+\.\d+)", text)
    if area_match:
        metadata["area"] = area_match.group(1).strip()

    # 청약일정 추출
    schedule_match = re.search(r"접수기간\s*:\s*(\d{4}\.\d{2}\.\d{2})\s*~\s*(\d{4}\.\d{2}\.\d{2})", text)
    if schedule_match:
        metadata["application_schedule"] = schedule_match.group(2).strip()

    # 특별공급조건 추출
    special_conditions_keywords = ["다자녀", "신혼", "생애", "노부모", "신생아", "청년"]
    for keyword in special_conditions_keywords:
        if keyword in text:
            metadata["special_supply_conditions"].append(keyword)

    return metadata

# PDF 파일 가져오기
crawl_pdfs = read_pdf_files(crawl_data_path)

# Crawl PDF 메타데이터 추출
crawl_metadata = []
if crawl_pdfs:
    for pdf_path in crawl_pdfs:
        print(f"Reading Crawl PDF: {pdf_path}")
        text = extract_text_from_pdf(pdf_path)
        if text:
            metadata = extract_metadata(text)
            crawl_metadata.append(metadata)

# # 메타데이터 출력
# for i, metadata in enumerate(crawl_metadata):
#     print(f"\nMetadata {i+1}:")
#     for key, value in metadata.items():
#         print(f"{key}: {value}")
# Out:
# Reading Crawl PDF: /Users/hyottz/Desktop/24f-houseplan/24f_daiv_houseplan/data/crawl_data/9.pdf
# Reading Crawl PDF: /Users/hyottz/Desktop/24f-houseplan/24f_daiv_houseplan/data/crawl_data/8.pdf
# Reading Crawl PDF: /Users/hyottz/Desktop/24f-houseplan/24f_daiv_houseplan/data/crawl_data/16.pdf
# Reading Crawl PDF: /Users/hyottz/Desktop/24f-houseplan/24f_daiv_houseplan/data/crawl_data/17.pdf
# Reading Crawl PDF: /Users/hyottz/Desktop/24f-houseplan/24f_daiv_houseplan/data/crawl_data/29.pdf
# Reading Crawl PDF: /Users/hyottz/Desktop/24f-houseplan/24f_daiv_houseplan/data/crawl_data/15.pdf
# Reading Crawl PDF: /Users/hyottz/Desktop/24f-houseplan/24f_daiv_houseplan/data/crawl_data/14.pdf
# Reading Crawl PDF: /Users/hyottz/Desktop/24f-houseplan/24f_daiv_houseplan/data/crawl_data/28.pdf
# Reading Crawl PDF: /Users/hyottz/Desktop/24f-houseplan/24f_daiv_houseplan/data/crawl_data/10.pdf
# Reading Crawl PDF: /Users/hyottz/Desktop/24f-houseplan/24f_daiv_houseplan/data/crawl_data/38.pdf
# Reading Crawl PDF: /Users/hyottz/Desktop/24f-houseplan/24f_daiv_houseplan/data/crawl_data/39.pdf
# Reading Crawl PDF: /Users/hyottz/Desktop/24f-houseplan/24f_daiv_houseplan/data/crawl_data/11.pdf
# Reading Crawl PDF: /Users/hyottz/Desktop/24f-houseplan/24f_daiv_houseplan/data/crawl_data/13.pdf
# Reading Crawl PDF: /Users/hyottz/Desktop/24f-houseplan/24f_daiv_houseplan/data/crawl_data/12.pdf
# Reading Crawl PDF: /Users/hyottz/Desktop/24f-houseplan/24f_daiv_houseplan/data/crawl_data/23.pdf
# Reading Crawl PDF: /Users/hyottz/Desktop/24f-houseplan/24f_daiv_houseplan/data/crawl_data/37.pdf
# Reading Crawl PDF: /Users/hyottz/Desktop/24f-houseplan/24f_daiv_houseplan/data/crawl_data/36.pdf
# Reading Crawl PDF: /Users/hyottz/Desktop/24f-houseplan/24f_daiv_houseplan/data/crawl_data/22.pdf
# Reading Crawl PDF: /Users/hyottz/Desktop/24f-houseplan/24f_daiv_houseplan/data/crawl_data/34.pdf
# Reading Crawl PDF: /Users/hyottz/Desktop/24f-houseplan/24f_daiv_houseplan/data/crawl_data/20.pdf
# Reading Crawl PDF: /Users/hyottz/Desktop/24f-houseplan/24f_daiv_houseplan/data/crawl_data/21.pdf
# Reading Crawl PDF: /Users/hyottz/Desktop/24f-houseplan/24f_daiv_houseplan/data/crawl_data/35.pdf
# Reading Crawl PDF: /Users/hyottz/Desktop/24f-houseplan/24f_daiv_houseplan/data/crawl_data/31.pdf
# Reading Crawl PDF: /Users/hyottz/Desktop/24f-houseplan/24f_daiv_houseplan/data/crawl_data/25.pdf
# Reading Crawl PDF: /Users/hyottz/Desktop/24f-houseplan/24f_daiv_houseplan/data/crawl_data/19.pdf
# Reading Crawl PDF: /Users/hyottz/Desktop/24f-houseplan/24f_daiv_houseplan/data/crawl_data/18.pdf
# Reading Crawl PDF: /Users/hyottz/Desktop/24f-houseplan/24f_daiv_houseplan/data/crawl_data/24.pdf
# Reading Crawl PDF: /Users/hyottz/Desktop/24f-houseplan/24f_daiv_houseplan/data/crawl_data/30.pdf
# Reading Crawl PDF: /Users/hyottz/Desktop/24f-houseplan/24f_daiv_houseplan/data/crawl_data/26.pdf
# Reading Crawl PDF: /Users/hyottz/Desktop/24f-houseplan/24f_daiv_houseplan/data/crawl_data/32.pdf
# Reading Crawl PDF: /Users/hyottz/Desktop/24f-houseplan/24f_daiv_houseplan/data/crawl_data/33.pdf
# Reading Crawl PDF: /Users/hyottz/Desktop/24f-houseplan/24f_daiv_houseplan/data/crawl_data/27.pdf
# Reading Crawl PDF: /Users/hyottz/Desktop/24f-houseplan/24f_daiv_houseplan/data/crawl_data/40.pdf
# Reading Crawl PDF: /Users/hyottz/Desktop/24f-houseplan/24f_daiv_houseplan/data/crawl_data/6.pdf
# Reading Crawl PDF: /Users/hyottz/Desktop/24f-houseplan/24f_daiv_houseplan/data/crawl_data/7.pdf
# Reading Crawl PDF: /Users/hyottz/Desktop/24f-houseplan/24f_daiv_houseplan/data/crawl_data/41.pdf
# Reading Crawl PDF: /Users/hyottz/Desktop/24f-houseplan/24f_daiv_houseplan/data/crawl_data/5.pdf
# Reading Crawl PDF: /Users/hyottz/Desktop/24f-houseplan/24f_daiv_houseplan/data/crawl_data/42.pdf
# Reading Crawl PDF: /Users/hyottz/Desktop/24f-houseplan/24f_daiv_houseplan/data/crawl_data/4.pdf
# Reading Crawl PDF: /Users/hyottz/Desktop/24f-houseplan/24f_daiv_houseplan/data/crawl_data/1.pdf
# Reading Crawl PDF: /Users/hyottz/Desktop/24f-houseplan/24f_daiv_houseplan/data/crawl_data/3.pdf
# Reading Crawl PDF: /Users/hyottz/Desktop/24f-houseplan/24f_daiv_houseplan/data/crawl_data/2.pdf
#
# Metadata 1:
# supply_name: ◎24.12월부산광역시국민임대예비입주자모집공고문_공고용
# region_name: 부산광역시 북구 화명신도시로 255(금곡동,율리마을주공아파트)
# supply_type: 국민임대
# area: 51.49
# application_schedule: 2024.12.26
# special_supply_conditions: []
#
# Metadata 2:
# supply_name: (정정)청주시_국민임대모집공고문(예비입주자)
# region_name: 충청북도 청주시 상당구 호미로 60(용암동,청주동남엘에이치3단지)
# supply_type: 국민임대
# area: 29.67
# application_schedule: 2025.01.06
# special_supply_conditions: []
#
# Metadata 3:
# supply_name: [충북지역본부]청년매입임대주택예비입주자모집공고(241226)
# region_name: 충청북도 청주시[상당구,서원구,청원구,흥덕구]
# supply_type: 매입임대
# area: None
# application_schedule: 2025.01.08
# special_supply_conditions: ['청년']
#
# Metadata 4:
# supply_name: [충북지역본부]신혼·신생아매입임대주택Ⅰ예비입주자모집공고(241226)
# region_name: 충청북도 [청주시 상당구,서원구,청원구,흥덕구,충주시]_단 한개의 주택군만 신청가능
# supply_type: 매입임대
# area: None
# application_schedule: 2025.01.08
# special_supply_conditions: ['신혼', '신생아']
#
# Metadata 5:
# supply_name: (강원) 24년 4차 신혼신생아매입1 입주자 모집 공고문
# region_name: None
# supply_type: 매입임대
# area: None
# application_schedule: 2025.01.08
# special_supply_conditions: ['신혼', '신생아']
#
# Metadata 6:
# supply_name: 24년4차_청년매입임대_입주자모집공고문(부산광역시)
# region_name: 부산광역시 금정구, 남구, 부산진구, 북구, 사상구, 사하구, 서구, 수영구, 해운대구
# supply_type: 매입임대
# area: None
# application_schedule: 2025.01.08
# special_supply_conditions: ['청년']
#
# Metadata 7:
# supply_name: 기숙사형매입임대_경남 주거2부 입주자 모집 공고문
# region_name: None
# supply_type: 매입임대
# area: None
# application_schedule: 2025.01.08
# special_supply_conditions: ['청년']
#
# Metadata 8:
# supply_name: (강원)24년4차신혼신생아매입임대2(전세형)공고문
# region_name: None
# supply_type: 매입임대
# area: None
# application_schedule: 2025.01.08
# special_supply_conditions: ['신혼', '신생아']
#
# Metadata 9:
# supply_name: 광주선운2A-1,A-3BL신혼희망타운행복주택입주자격완화추가모집공고문('24.12.20.)
# region_name: 광주광역시 광산구 운수동 광주선운2 공공주택지구내 A-1BL
# supply_type: 행복주택
# area: 55.57
# application_schedule: 2025.01.07
# special_supply_conditions: ['신혼']
#
# Metadata 10:
# supply_name: 2412_24년청년매입임대_표준입주자모집공고문
# region_name: None
# supply_type: 매입임대
# area: None
# application_schedule: 2025.01.08
# special_supply_conditions: ['청년']
#
# Metadata 11:
# supply_name: 24년 4차 대구경북 신혼ㆍ신생아Ⅰ매입임대 입주자 모집 공고문
# region_name: None
# supply_type: 매입임대
# area: None
# application_schedule: 2025.01.08
# special_supply_conditions: ['신혼', '신생아']
#
# Metadata 12:
# supply_name: (241220)과천지식정보타운_S11BL_행복주택(리츠)_입주자_모집_공고문
# region_name: 경기도 과천시 갈현동 593-1
# supply_type: 행복주택
# area: 16.8
# application_schedule: 2025.01.08
# special_supply_conditions: ['신혼', '청년']
#
# Metadata 13:
# supply_name: 청년매입(경남본부_주거복지사업2부) 입주자 모집 공고문
# region_name: None
# supply_type: 매입임대
# area: None
# application_schedule: 2025.01.08
# special_supply_conditions: ['청년']
#
# Metadata 14:
# supply_name: 241216경북서부지역국민임대예비입주자모집공고문
# region_name: 경상북도 구미시 인동54길 25(구평동,휴먼시아)
# supply_type: 국민임대
# area: 36.55
# application_schedule: 2025.01.06
# special_supply_conditions: []
#
# Metadata 15:
# supply_name: 2.24년4차신혼·신생아매입임대Ⅰ예비입주자모집공고문(경기북부)
# region_name: [경기도] 고양시, 김포시, 양주시, 의정부시, 파주시, 포천시, 하남시
# supply_type: 매입임대
# area: None
# application_schedule: 2025.01.08
# special_supply_conditions: ['신혼', '신생아']
#
# Metadata 16:
# supply_name: 2412_24년신혼·신생아매입임대Ⅱ(전세형)_표준입주자모집공고문
# region_name: None
# supply_type: 매입임대
# area: None
# application_schedule: 2025.01.08
# special_supply_conditions: ['신혼', '신생아']
#
# Metadata 17:
# supply_name: 2412_24년신혼·신생아매입임대Ⅰ_표준입주자모집공고문
# region_name: None
# supply_type: 매입임대
# area: None
# application_schedule: 2025.01.08
# special_supply_conditions: ['신혼', '신생아']
#
# Metadata 18:
# supply_name: 1.24년4차신혼·신생아매입임대Ⅱ(전세형)예비입주자모집공고문(경기북부)
# region_name: [경기도] 고양시, 김포시
# supply_type: 매입임대
# area: None
# application_schedule: 2025.01.08
# special_supply_conditions: ['신혼', '신생아']
#
# Metadata 19:
# supply_name: 24년_4차_청년매입임대주택_공고문_(광주전남)
# region_name: None
# supply_type: 매입임대
# area: None
# application_schedule: 2025.01.08
# special_supply_conditions: ['청년']
#
# Metadata 20:
# supply_name: 24년4차_신혼·신생아매입임대Ⅰ_입주자모집공고문(부산광역시)
# region_name: 부산 금정구, 남구, 동구, 동래구, 부산진구, 사상구, 사하구, 서구, 수영구, 연제구, 해운대구
# supply_type: 매입임대
# area: None
# application_schedule: 2025.01.08
# special_supply_conditions: ['신혼', '신생아']
#
# Metadata 21:
# supply_name: 24년4차_신혼·신생아매입임대Ⅱ(전세형)_입주자모집공고문(부산광역시)
# region_name: 부산 동래구, 부산진구, 북구, 사상구, 사하구
# supply_type: 매입임대
# area: None
# application_schedule: 2025.01.08
# special_supply_conditions: ['신혼', '신생아']
#
# Metadata 22:
# supply_name: 24년_4차_신혼신생아Ⅰ매입임대주택_공고문_광주전남)
# region_name: None
# supply_type: 매입임대
# area: None
# application_schedule: 2025.01.08
# special_supply_conditions: ['신혼', '신생아']
#
# Metadata 23:
# supply_name: (강원) 24년 4차 청년매입임대 입주자 모집 공고문
# region_name: None
# supply_type: 매입임대
# area: None
# application_schedule: 2025.01.08
# special_supply_conditions: ['청년']
#
# Metadata 24:
# supply_name: 2.24년4차청년매입임대예비입주자모집공고문(경기북부)
# region_name: [경기도] 고양시, 구리시, 김포시, 의정부시, 파주시
# supply_type: 매입임대
# area: None
# application_schedule: 2025.01.08
# special_supply_conditions: ['신혼', '청년']
#
# Metadata 25:
# supply_name: 24년4차_기숙사형매입임대_입주자모집공고문(부산광역시)
# region_name: 부산 금정구, 부산진구
# supply_type: 매입임대
# area: None
# application_schedule: 2025.01.08
# special_supply_conditions: ['청년']
#
# Metadata 26:
# supply_name: [충북지역본부]신혼·신생아매입임대주택Ⅱ(전세형)예비입주자모집공고(241226)
# region_name: 충청북도[청주시 상당구,서원구,흥덕구,충주시,제천시]_단 한개의 주택군만 신청 가능
# supply_type: 매입임대
# area: None
# application_schedule: 2025.01.08
# special_supply_conditions: ['신혼', '신생아']
#
# Metadata 27:
# supply_name: 20241226함양군다자녀예비입주자모집공고문
# region_name: None
# supply_type: 매입임대
# area: None
# application_schedule: 2025.01.17
# special_supply_conditions: ['다자녀']
#
# Metadata 28:
# supply_name: (공고문)24-2차경기남부지역본부다자녀매입임대주택예비입주자모집공고
# region_name: 경기 안산·시흥
# supply_type: 매입임대
# area: None
# application_schedule: 2025.01.08
# special_supply_conditions: ['다자녀', '신생아']
#
# Metadata 29:
# supply_name: 2.24년4차기숙사형청년주택예비입주자모집공고문(경기북부)
# region_name: [경기도] 구리시(여성전용 1호)
# supply_type: 매입임대
# area: None
# application_schedule: 2025.01.08
# special_supply_conditions: ['청년']
#
# Metadata 30:
# supply_name: (공고문)24-2차경기남부지역본부기숙사형청년주택모집공고문
# region_name: None
# supply_type: 매입임대
# area: None
# application_schedule: 2025.01.08
# special_supply_conditions: ['청년']
#
# Metadata 31:
# supply_name: 24년_4차_신혼신생아매입임대주택Ⅱ_공고문_(광주전남)
# region_name: None
# supply_type: 매입임대
# area: None
# application_schedule: 2025.01.08
# special_supply_conditions: ['신혼', '신생아']
#
# Metadata 32:
# supply_name: 24년12월 기숙사형매입임대 예비입주자 모집공고
# region_name: None
# supply_type: 매입임대
# area: None
# application_schedule: 2025.01.08
# special_supply_conditions: ['청년']
#
# Metadata 33:
# supply_name: 24년 4차 신혼ㆍ신생아Ⅱ_전세형 입주자 모집 공고문
# region_name: None
# supply_type: 매입임대
# area: None
# application_schedule: 2025.01.08
# special_supply_conditions: ['신혼', '신생아']
#
# Metadata 34:
# supply_name: 경주시,영천시,포항시_국민임대주택_예비입주자_모집_공고(2024.12.16)
# region_name: 경상북도 경주시 건천읍 대곡용명길 27(건천휴먼시아)
# supply_type: 국민임대
# area: 33.48
# application_schedule: 2025.01.07
# special_supply_conditions: []
#
# Metadata 35:
# supply_name: (최종)대전광역시유성구국민임대주택예비입주자모집공고문(공고일2024.12.16)
# region_name: 대전광역시 유성구 원신흥로 37(원신흥동,도안휴먼시아10단지)
# supply_type: 국민임대
# area: 33.82
# application_schedule: 2025.01.08
# special_supply_conditions: []
#
# Metadata 36:
# supply_name: 24년 4차 기숙사형 청년주택 입주자 모집 공고문
# region_name: None
# supply_type: 매입임대
# area: None
# application_schedule: 2025.01.08
# special_supply_conditions: ['청년']
#
# Metadata 37:
# supply_name: 함안칠원국민임대주택예비입주자모집공고_24.12.16_게시용
# region_name: 경상남도 함안군 칠원읍 구성길 141(함안칠원엘에이치아파트)
# supply_type: 국민임대
# area: 36.5
# application_schedule: 2025.01.08
# special_supply_conditions: []
#
# Metadata 38:
# supply_name: 24년 4차 대구경북 청년매입임대 모집 공고문
# region_name: None
# supply_type: 매입임대
# area: None
# application_schedule: 2025.01.08
# special_supply_conditions: ['청년']
#
# Metadata 39:
# supply_name: 밀양내이국민임대주택예비입주자모집공고_24.12.16_게시용
# region_name: 경상남도 밀양시 창밀로 3535(내이동,밀양내이엘에이치아파트) 3535 (밀양내이 LH아파트)
# supply_type: 국민임대
# area: 36.88
# application_schedule: 2025.01.08
# special_supply_conditions: []
#
# Metadata 40:
# supply_name: 241213강릉교동,철원철원행복주택입주자공고문(안)
# region_name: 강원특별자치도 강릉시 강릉대로313번길 29(포남동)
# supply_type: 행복주택
# area: 21.85
# application_schedule: 2025.01.10
# special_supply_conditions: ['청년']
#
# Metadata 41:
# supply_name: 창원시국민임대주택예비입주자모집공고_24.12.16_게시용
# region_name: 경상남도 창원시 진해구 냉천로 192(자은동)
# supply_type: 국민임대
# area: 26.83
# application_schedule: 2025.01.08
# special_supply_conditions: []
#
# Metadata 42:
# supply_name: 사천용현국민임대주택예비자입주자모집공고문('24.12.16.)
# region_name: 경상남도 사천시 용현면 진삼로 580(용현휴먼시아)
# supply_type: 국민임대
# area: 36.52
# application_schedule: 2025.01.07
# special_supply_conditions: ['신혼']

# %% [markdown]
# # 2. keyword parsing

# %%
import pandas as pd
import numpy as np

# api_metadata를 DataFrame으로 변환
api_data = pd.DataFrame(api_metadata)
crawl_data = pd.DataFrame(crawl_metadata)

# %%
# 결합
combined_data = pd.concat([api_data, crawl_data], ignore_index=True)

# 결과 확인
print(combined_data.head())
# Out:
#              supply_name                   region_name application_schedule  \
# 0  서대문 센트럴 아이파크(임의공급 8차)    서울특별시 서대문구 홍은동 11-111번지 일원           2025-01-10
# 1        판교밸리자이 3단지 오피스텔         경기도 성남시 수정구 대왕판교로 961           2025-01-10
# 2      천안 두정역 양우내안애 퍼스트로  충청남도 천안시 서북구 두정동 393-11번지 일원           2025-01-13
# 3   상월곡역 장위아트포레(도시형생활주택)          서울특별시 성북구 석관동 338-18           2025-01-13
# 4    부산에코델타시티 대방 엘리움 리버뷰  부산광역시 강서구 에코델타시티 공동주택용지 31BL           2025-01-16
#
#        special_supply_conditions enter_day  max_supply_price supply_type area
# 0                             []   2025.06               NaN         NaN  NaN
# 1                             []      None           95600.0         NaN  NaN
# 2  [다자녀, 신혼부, 생애최, 노부모, 신생아, 청년]   2027.12           39000.0         NaN  NaN
# 3                             []      None           22500.0         NaN  NaN
# 4  [다자녀, 신혼부, 생애최, 노부모, 신생아, 청년]   2027.10          108847.0         NaN  NaN

# %%
# 입력 조건 - Front-End와 연결예정

user_input = {
    #"supply_name": "공급 A",
    "region_name": "인천",
    #"application_schedule": "2025-01-01",
    "special_supply_conditions": ["청년"],
    #"enter_day": "2025.01",
    #"max_supply_price": 500_000_000,
    #"supply_type": "임대주택",
    #"area": 80
}

# %%
# 데이터 통합
combined_data = pd.concat([api_data, crawl_data], ignore_index=True)

# 데이터 전처리 함수
def preprocess_data(data):
    # 날짜 및 숫자 변환
    data["enter_day"] = pd.to_datetime(data["enter_day"], format="%Y.%m", errors="coerce")
    data["max_supply_price"] = pd.to_numeric(data["max_supply_price"], errors="coerce")
    data["special_supply_conditions"] = data["special_supply_conditions"].apply(
        lambda x: ", ".join(x) if isinstance(x, list) else ""
    )  # 리스트를 문자열로 변환
    data["area"] = pd.to_numeric(data["area"], errors="coerce")  # 면적 숫자 변환
    return data

# 필터링 함수
def filter_data(data, user_input):
    filtered_data = data.copy()

    # 각 조건에 대해 필터링 (user_input에 값이 존재하는 경우만)
    if "supply_name" in user_input:
        filtered_data = filtered_data[
            filtered_data["supply_name"].str.contains(user_input["supply_name"], na=False)
        ]
    if "region_name" in user_input:
        filtered_data = filtered_data[
            filtered_data["region_name"].str.contains(user_input["region_name"], na=False)
        ]
    if "application_schedule" in user_input:
        filtered_data = filtered_data[
            filtered_data["application_schedule"] >= user_input["application_schedule"]
        ]
    if "special_supply_conditions" in user_input:
        filtered_data = filtered_data[
            filtered_data["special_supply_conditions"].str.contains(
                "|".join(user_input["special_supply_conditions"]), na=False
            )
        ]
    if "enter_day" in user_input:
        user_enter_date = pd.to_datetime(user_input["enter_day"], format="%Y.%m", errors="coerce")
        filtered_data = filtered_data[filtered_data["enter_day"] >= user_enter_date]
    if "max_supply_price" in user_input:
        filtered_data = filtered_data[
            filtered_data["max_supply_price"] <= user_input["max_supply_price"]
        ]
    if "supply_type" in user_input:
        filtered_data = filtered_data[
            filtered_data["supply_type"].str.contains(user_input["supply_type"], na=False)
        ]
    if "area" in user_input:
        filtered_data = filtered_data[
            filtered_data["area"] >= user_input["area"]
        ]

    return filtered_data

# 추천 알고리즘
def recommend_supply(data, user_input):
    # 데이터 전처리
    data = preprocess_data(data)

    # 필터링
    filtered_data = filter_data(data, user_input)

    # 정렬 (max_supply_price → enter_day → special_supply_conditions 순서)
    filtered_data = filtered_data.sort_values(
        by=["max_supply_price", "enter_day", "special_supply_conditions"],
        ascending=[True, True, False]
    )

    return filtered_data

# 추천 결과
recommended_supplies = recommend_supply(combined_data, user_input)

# 결과 출력 (nan이면 미출력)
if not recommended_supplies.empty:
    print("\n=== 추천 청약 목록 ===")
    for i, row in recommended_supplies.iterrows():
        print(f"공급명: {row['supply_name']}")
        print(f"지역: {row['region_name']}")
        print(f"청약일정: {row['application_schedule']}")
        
        # 특별공급조건 출력 (값이 있는 경우만)
        if pd.notna(row["special_supply_conditions"]) and row["special_supply_conditions"]:
            print(f"특별공급조건: {row['special_supply_conditions']}")
        
        # 입주 예정월 출력 (값이 있는 경우만)
        if pd.notna(row["enter_day"]):
            print(f"입주 예정월: {row['enter_day'].strftime('%Y.%m')}")
        
        # 최대 공급금액 출력 (값이 있는 경우만)
        if pd.notna(row["max_supply_price"]):
            print(f"최대 공급금액: {row['max_supply_price']}")
        
        # 공급유형 출력 (값이 있는 경우만)
        if pd.notna(row["supply_type"]):
            print(f"공급유형: {row['supply_type']}")
        
        # 면적 출력 (값이 있는 경우만)
        if pd.notna(row["area"]):
            print(f"면적: {row['area']}㎡")
        
        print("-" * 30)
else:
    print("조건에 맞는 청약 정보를 찾을 수 없습니다.")
# Out:
# === 추천 청약 목록 ===
# 공급명: 인천강화서희스타힐스 1단지(조합원 취소세대)
# 지역: 인천광역시 강화군 선원면 창리456번지 일원
# 청약일정: 2025-01-17
# 특별공급조건: 다자녀, 신혼부, 생애최, 노부모, 신생아, 청년
# 입주 예정월: 2025.02
# 최대 공급금액: 37574.0
# ------------------------------
